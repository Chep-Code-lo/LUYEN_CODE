# %% [markdown]
# #**2.1 Số lớn không dấu**
#
# ##**Question 1**
# **Coder:**
#
# Viết phép cộng hai số nguyên lớn theo cấu trúc operator, dùng struct bigint{ mã code }, đưa ra các test case ví dụ cụ thể và lưu ý trường hợp số 0 ở đầu bằng ngôn ngữ C++
#
# **ChatGPT:**
#
# Đây là chương trình C++ để xử lý số nguyên lớn (`BigInt`) và hỗ trợ phép cộng thông qua toán tử `operator+`.
# Chương trình cũng bao gồm các test case cụ thể và hỗ trợ nhập từ bàn phím.
# ```cpp
# #include <iostream>
# #include <string>
# #include <algorithm>
# struct BigInt{
#     std::string value;
#     BigInt(std::string val){
#         val.erase(0, std::min(val.find_first_not_of('0'), val.size()-1));
#         value = val;
#     }
#     BigInt operator+(const BigInt &other) const {
#         std::string num1 = value;
#         std::string num2 = other.value;
#         std::string result = "";
#         int carry = 0;
#         if (num1.length() < num2.length())
#             std::swap(num1, num2);
#         int n1 = num1.length(), n2 = num2.length();
#         int diff = n1 - n2;
#         for (int i = n2 - 1; i >= 0; i--) {
#             int sum = (num1[i + diff] - '0') + (num2[i] - '0') + carry;
#             result.push_back((sum % 10) + '0');
#             carry = sum / 10;
#         }
#         for (int i = diff - 1; i >= 0; i--) {
#             int sum = (num1[i] - '0') + carry;
#             result.push_back((sum % 10) + '0');
#             carry = sum / 10;
#         }
#         if (carry)
#             result.push_back(carry + '0');
#
#         std::reverse(result.begin(), result.end());
#         return BigInt(result);
#     }
#     friend std::ostream& operator<<(std::ostream &os, const BigInt &num) {
#         os << num.value;
#         return os;
#     }
#     friend std::istream& operator>>(std::istream &is, BigInt &num) {
#         is >> num.value;
#         num.value.erase(0, std::min(num.value.find_first_not_of('0'), num.value.size()-1));
#         return is;
#     }
# };
# int main(){
#     BigInt a("12345678901234567890");
#     BigInt b("98765432109876543210");
#     std::cout << "Sum: " << (a + b) << std::endl;
#     BigInt c("99999999999999999999");
#     BigInt d("1");
#     std::cout << "Sum: " << (c + d) << std::endl;
#     BigInt e("0000000123");
#     BigInt f("77");
#     std::cout << "Sum: " << (e + f) << std::endl;
#     BigInt x, y;
#     std::cout << "Nhập số thứ nhất: ";
#     std::cin >> x;
#     std::cout << "Nhập số thứ hai: ";
#     std::cin >> y;
#     std::cout << "Tổng hai số là: " << (x + y) << std::endl;
#     return 0;
# }
# ```
# ### **Giải thích**
#
# #### **Xử lý số 0 ở đầu**
# - Khi khởi tạo `BigInt`, chương trình sẽ loại bỏ các số `0` ở đầu để tránh các trường hợp như `"000123"` bị giữ nguyên.
# - Điều này đảm bảo rằng mọi số được lưu trữ dưới dạng chuẩn, không có số `0` thừa.
#
# #### **Cộng hai số**
# - Thực hiện phép cộng từ cuối lên đầu, giống như cách chúng ta làm trên giấy.
# - Duy trì một biến `carry` để lưu giá trị dư nếu tổng hai chữ số vượt quá `9`.
# - Sau khi cộng xong tất cả các chữ số, nếu còn `carry`, ta thêm vào kết quả.
# - Kết quả cuối cùng được đảo ngược để có đúng thứ tự.
#
# ### **Test Cases**
#
# | Biểu thức | Kết quả mong đợi |
# |-----------|----------------|
# | `12345678901234567890 + 98765432109876543210` | `111111111011111111100` |
# | `99999999999999999999 + 1` | `100000000000000000000` (Kiểm tra trường hợp vượt qua giới hạn số nguyên) |
# | `0000000123 + 77` | `200` (Kiểm tra xử lý số `0` ở đầu) |
#
# ### **Lợi ích**
# - Chương trình có thể xử lý các số nguyên lớn mà không bị giới hạn bởi kiểu dữ liệu nguyên thủy của C++. 🚀
#
# ###**Question 2**
# **Coder**:
#
# Tiếp tục như thế với phép trừ hai số nguyên lớn
#
# **ChatGPT**:
# ## C++: **Phép Trừ Hai Số Nguyên Lớn (BigInt)**
#
# ### 📌 Tính năng chính
# ✅ Hỗ trợ trừ hai số lớn không giới hạn kích thước.
# ✅ Xử lý trường hợp số 0 ở đầu.
# ✅ Hỗ trợ số âm khi kết quả nhỏ hơn 0.
# ✅ Có các test case minh họa.
# ---
# ### 📝 **Giải thích**
#
# #### **Xử lý số 0 ở đầu**
# - Khi khởi tạo `BigInt`, chương trình sẽ loại bỏ các số `0` ở đầu để tránh các trường hợp như `"000123"` bị giữ nguyên.
# - Điều này đảm bảo rằng mọi số được lưu trữ dưới dạng chuẩn, không có số `0` thừa.
#
# #### **Trừ hai số**
# - So sánh hai số để xác định số lớn hơn và số nhỏ hơn.
# - Nếu số bị trừ nhỏ hơn số trừ, kết quả sẽ là số âm.
# - Thực hiện phép trừ từ cuối lên đầu, giống như cách làm thủ công trên giấy.
# - Nếu một chữ số nhỏ hơn chữ số bị trừ, mượn từ chữ số lớn hơn tiếp theo.
#
# ### **Test Cases**
#
# | **Biểu thức** | **Kết quả mong đợi** |
# |-----------|----------------|
# | `98765432109876543210 - 12345678901234567890` | `86419753208641975320` |
# | `100000000000000000000 - 99999999999999999999` | `1` (Kiểm tra trường hợp gần bằng nhau) |
# | `77 - 0000000123` | `-46` (Kiểm tra xử lý số `0` ở đầu và kết quả âm) |
# | `99999999999999999999 - 1` | `99999999999999999998` (Kiểm tra giới hạn lớn) |
#
# ---
# ### 📝 **Mã C++**
# ```cpp
# #include <iostream>
# #include <string>
# #include <algorithm>
# struct BigInt {
#     std::string value;
#     bool isNegative = false;
#     // Constructor: Khởi tạo BigInt từ chuỗi số, loại bỏ số 0 ở đầu
#     BigInt(std::string val) {
#         if (val[0] == '-') {  // Kiểm tra nếu số là số âm
#             isNegative = true;
#             val = val.substr(1); // Loại bỏ dấu '-'
#         }
#         // Loại bỏ số 0 ở đầu (trừ trường hợp số 0)
#         val.erase(0, std::min(val.find_first_not_of('0'), val.size()-1));
#         value = val;
#         if (value == "0") isNegative = false; // Tránh trường hợp "-0"
#     }
#     // So sánh hai số (chỉ xét giá trị tuyệt đối)
#     bool operator<(const BigInt &other) const {
#         if (value.length() != other.value.length())
#             return value.length() < other.value.length();
#         return value < other.value;
#     }
#
#     // Phép trừ hai số nguyên lớn
#     BigInt operator-(const BigInt &other) const {
#         if (*this < other) {
#             // Nếu số bị trừ nhỏ hơn số trừ, kết quả sẽ là số âm
#             return BigInt("-" + (other - *this).value);
#         }
#         std::string num1 = value, num2 = other.value, result = "";
#         int carry = 0, diff = num1.length() - num2.length();
#         // Trừ từng chữ số từ cuối lên đầu
#         for (int i = num2.length() - 1; i >= 0; i--) {
#             int sub = (num1[i + diff] - '0') - (num2[i] - '0') - carry;
#             if (sub < 0) {
#                 sub += 10;  // Mượn từ chữ số lớn hơn bên trái
#                 carry = 1;
#             } else {
#                 carry = 0;
#             }
#             result.push_back(sub + '0');
#         }
#         // Xử lý phần còn lại của số lớn hơn
#         for (int i = diff - 1; i >= 0; i--) {
#             int sub = (num1[i] - '0') - carry;
#             if (sub < 0) {
#                 sub += 10;
#                 carry = 1;
#             } else {
#                 carry = 0;
#             }
#             result.push_back(sub + '0');
#         }
#         // Loại bỏ số 0 ở đầu kết quả
#         while (result.length() > 1 && result.back() == '0') {
#             result.pop_back();
#         }
#         std::reverse(result.begin(), result.end()); // Đảo ngược chuỗi để có đúng thứ tự
#         return BigInt(result);
#     }
#     // Toán tử nhập từ bàn phím
#     friend std::istream& operator>>(std::istream &is, BigInt &num) {
#         is >> num.value;
#         num = BigInt(num.value); // Gọi constructor để xử lý số 0 ở đầu
#         return is;
#     }
#     // Toán tử xuất ra màn hình
#     friend std::ostream& operator<<(std::ostream &os, const BigInt &num) {
#         if (num.isNegative) os << "-";
#         os << num.value;
#         return os;
#     }
# };
# int main() {
#     // Test case 1: 98765432109876543210 - 12345678901234567890
#     BigInt a("98765432109876543210");
#     BigInt b("12345678901234567890");
#     std::cout << "98765432109876543210 - 12345678901234567890 = " << (a - b) << std::endl;
#     // Test case 2: 100000000000000000000 - 99999999999999999999
#     BigInt c("100000000000000000000");
#     BigInt d("99999999999999999999");
#     std::cout << "100000000000000000000 - 99999999999999999999 = " << (c - d) << std::endl;
#     // Test case 3: 77 - 0000000123 (Kết quả âm)
#     BigInt e("77");
#     BigInt f("123");
#     std::cout << "77 - 123 = " << (e - f) << std::endl;
#     // Test case 4: 99999999999999999999 - 1
#     BigInt g("99999999999999999999");
#     BigInt h("1");
#     std::cout << "99999999999999999999 - 1 = " << (g - h) << std::endl;
#     // Test nhập từ bàn phím
#     BigInt x, y;
#     std::cout << "Nhập số thứ nhất: ";
#     std::cin >> x;
#     std::cout << "Nhập số thứ hai: ";
#     std::cin >> y;
#     std::cout << "Kết quả phép trừ: " << (x - y) << std::endl;
#     return 0;
# }
# ```
# ---
#
# ### 📌 Lưu ý
# ✔️ **Xử lý số 0 ở đầu**: Khi nhập từ bàn phím hoặc tính toán xong, chương trình sẽ loại bỏ các số `0` vô nghĩa.
# ✔️ **Xử lý số âm**: Nếu số bị trừ nhỏ hơn số trừ, kết quả sẽ có dấu `-`.
# ✔️ **Không bị giới hạn bởi kiểu dữ liệu**: Không sử dụng kiểu `int` hay `long long`, giúp xử lý số cực lớn.
#
# ###**Question 3**
# **Coder**:
#
# Tiếp tục như thế với Phép nhân một số nguyên lớn với với số nguyên nhỏ (kiểu int)
#
# **ChatGPT**:
#
# # **🚀 PHÉP NHÂN SỐ NGUYÊN LỚN VỚI SỐ NGUYÊN NHỎ (BIGINT × INT)**
#
# ## **🔹 TÍNH NĂNG CHÍNH**
# ✅ Hỗ trợ nhân số lớn (`BigInt`) với số nguyên nhỏ (`int`).
# ✅ Xử lý số 0 ở đầu và kết quả âm.
# ✅ Không giới hạn kích thước số lớn.
# ✅ Bao gồm test cases minh họa.
#
# ---
#
# ## **🔹 GIẢI THÍCH**
#
# ### **🔸 XỬ LÝ SỐ 0 Ở ĐẦU**
# - Khi khởi tạo `BigInt`, chương trình sẽ loại bỏ các số `0` ở đầu để đảm bảo lưu trữ chuẩn.
#
# ### **🔸 CÁCH THỰC HIỆN PHÉP NHÂN**
# - Thực hiện nhân từng chữ số từ cuối lên đầu với `int`, giống cách nhân trên giấy.
# - Sử dụng biến `carry` để xử lý trường hợp nhân vượt quá 9.
# - Đảo ngược kết quả sau khi tính toán để có đúng thứ tự.
# - Nếu kết quả bằng 0, lưu `"0"` thay vì chuỗi rỗng.
#
# ---
#
# ## **🔹 TEST CASES**
#
# | Biểu thức | Kết quả mong đợi |
# |-----------|----------------|
# | `12345678901234567890 × 5` | `61728394506172839450` |
# | `99999999999999999999 × 2` | `199999999999999999998` |
# | `77 × 0` | `0` (Kiểm tra nhân với 0) |
# | `-123456789 × 3` | `-370370367` (Kiểm tra số âm) |
#
# ---
#
# ## **🔹 MÃ C++**
#
# ```cpp
# #include <iostream>
# #include <string>
# #include <algorithm>
#
# struct BigInt {
#     std::string value;
#     bool isNegative = false;
#
#     // Constructor: Khởi tạo BigInt từ chuỗi số, xử lý số âm và loại bỏ số 0 ở đầu
#     BigInt(std::string val) {
#         if (val[0] == '-') {
#             isNegative = true;
#             val = val.substr(1); // Loại bỏ dấu '-'
#         }
#         val.erase(0, std::min(val.find_first_not_of('0'), val.size()-1)); // Xóa số 0 ở đầu
#         value = val;
#         if (value == "0") isNegative = false; // Tránh trường hợp "-0"
#     }
#
#     // Toán tử nhân BigInt với số nguyên nhỏ (int)
#     BigInt operator*(int num) const {
#         if (num == 0) return BigInt("0"); // Nếu nhân với 0, trả về 0 ngay lập tức
#
#         bool resultNegative = isNegative ^ (num < 0); // Kết quả âm nếu một trong hai số âm
#         num = std::abs(num); // Lấy giá trị tuyệt đối của số nhỏ
#         std::string res = "";
#         int carry = 0;
#
#         // Nhân từng chữ số từ cuối lên đầu
#         for (int i = value.length() - 1; i >= 0; i--) {
#             int product = (value[i] - '0') * num + carry;
#             res.push_back((product % 10) + '0'); // Lấy phần đơn vị của tích
#             carry = product / 10; // Lưu phần nhớ
#         }
#
#         // Thêm phần nhớ còn lại nếu có
#         while (carry) {
#             res.push_back((carry % 10) + '0');
#             carry /= 10;
#         }
#
#         std::reverse(res.begin(), res.end()); // Đảo ngược kết quả để đúng thứ tự
#         return resultNegative ? BigInt("-" + res) : BigInt(res); // Thêm dấu âm nếu cần
#     }
#
#     // Toán tử nhập từ bàn phím
#     friend std::istream& operator>>(std::istream &is, BigInt &num) {
#         is >> num.value;
#         num = BigInt(num.value); // Gọi constructor để xử lý số 0 ở đầu
#         return is;
#     }
#
#     // Toán tử xuất ra màn hình
#     friend std::ostream& operator<<(std::ostream &os, const BigInt &num) {
#         if (num.isNegative) os << "-"; // In dấu âm nếu có
#         os << num.value;
#         return os;
#     }
# };
#
# int main() {
#     // Test case 1: 12345678901234567890 × 5
#     BigInt a("12345678901234567890");
#     int b = 5;
#     std::cout << "12345678901234567890 × 5 = " << (a * b) << std::endl;
#
#     // Test case 2: 99999999999999999999 × 2
#     BigInt c("99999999999999999999");
#     int d = 2;
#     std::cout << "99999999999999999999 × 2 = " << (c * d) << std::endl;
#
#     // Test case 3: 77 × 0 (Kiểm tra nhân với 0)
#     BigInt e("77");
#     int f = 0;
#     std::cout << "77 × 0 = " << (e * f) << std::endl;
#
#     // Test case 4: -123456789 × 3 (Kiểm tra số âm)
#     BigInt g("-123456789");
#     int h = 3;
#     std::cout << "-123456789 × 3 = " << (g * h) << std::endl;
#
#     // Test nhập từ bàn phím
#     BigInt x;
#     int y;
#     std::cout << "Nhập số lớn: ";
#     std::cin >> x;
#     std::cout << "Nhập số nhỏ: ";
#     std::cin >> y;
#     std::cout << "Kết quả phép nhân: " << (x * y) << std::endl;
#
#     return 0;
# }
# ```
# ---
# ## **🔹 LƯU Ý**
# ✔️ **Xử lý số 0 ở đầu**: Khi nhập hoặc tính toán, chương trình loại bỏ số `0` vô nghĩa.
# ✔️ **Xử lý số âm**: Nếu một trong hai số là số âm, kết quả sẽ có dấu `-`.
# ✔️ **Không giới hạn bởi kiểu dữ liệu**: Không sử dụng `int` hay `long long`, giúp xử lý số cực lớn.
#
# ###**Question 4**
# **Coder**:
#
# Tiếp tục như thế với phép nhân hai số nguyên lớn
#
# **ChatGPT**:
#
# # **🚀 PHÉP NHÂN HAI SỐ NGUYÊN LỚN (BIGINT × BIGINT)**
#
# ## **🔹 TÍNH NĂNG CHÍNH**
# ✅ Hỗ trợ nhân hai số nguyên lớn không giới hạn kích thước.
# ✅ Xử lý số 0 ở đầu và kết quả âm.
# ✅ Cải thiện hiệu suất bằng thuật toán nhân thủ công.
# ✅ Bao gồm test cases minh họa.
#
# ---
#
# ## **🔹 GIẢI THÍCH**
#
# ### **🔸 XỬ LÝ SỐ 0 Ở ĐẦU**
# - Khi khởi tạo `BigInt`, chương trình sẽ loại bỏ các số `0` ở đầu để đảm bảo lưu trữ chuẩn.
#
# ### **🔸 CÁCH THỰC HIỆN PHÉP NHÂN**
# - Duyệt từng chữ số của số thứ nhất và nhân với từng chữ số của số thứ hai, giống cách nhân trên giấy.
# - Sử dụng mảng để lưu kết quả trung gian và cộng dồn các phần tử.
# - Xử lý dấu âm: Nếu hai số trái dấu thì kết quả là số âm.
# - Loại bỏ các số `0` dư thừa ở đầu kết quả.
#
# ---
#
# ## **🔹 TEST CASES**
#
# | Biểu thức | Kết quả mong đợi |
# |-----------|----------------|
# | `12345678901234567890 × 98765432109876543210` | `1219326311370217952237463801111263526900` |
# | `999999999 × 999999999` | `999999998000000001` |
# | `5000 × 0` | `0` (Kiểm tra nhân với 0) |
# | `-123456 × 7890` | `-974067840` (Kiểm tra số âm) |
#
# ---
#
# ## **🔹 MÃ C++**
#
# ```cpp
# #include <iostream>
# #include <string>
# #include <vector>
# #include <algorithm>
#
# struct BigInt {
#     std::string value;
#     bool isNegative = false;
#
#     // Constructor: Khởi tạo BigInt từ chuỗi số, xử lý dấu và loại bỏ số 0 ở đầu
#     BigInt(std::string val) {
#         if (val[0] == '-') {
#             isNegative = true;
#             val = val.substr(1); // Loại bỏ dấu '-'
#         }
#         val.erase(0, std::min(val.find_first_not_of('0'), val.size()-1)); // Xóa số 0 ở đầu
#         value = val;
#         if (value == "0") isNegative = false; // Tránh trường hợp "-0"
#     }
#
#     // Toán tử nhân BigInt với BigInt
#     BigInt operator*(const BigInt& other) const {
#         if (value == "0" || other.value == "0") return BigInt("0"); // Nếu một trong hai số là 0, kết quả là 0
#
#         bool resultNegative = isNegative ^ other.isNegative; // Xác định dấu kết quả
#         int len1 = value.size(), len2 = other.value.size();
#         std::vector<int> result(len1 + len2, 0); // Mảng chứa kết quả trung gian
#
#         // Nhân từng chữ số từ phải sang trái (giống nhân trên giấy)
#         for (int i = len1 - 1; i >= 0; i--) {
#             for (int j = len2 - 1; j >= 0; j--) {
#                 int mul = (value[i] - '0') * (other.value[j] - '0'); // Nhân hai chữ số
#                 int sum = mul + result[i + j + 1]; // Cộng vào vị trí hiện tại
#
#                 result[i + j + 1] = sum % 10; // Lưu phần đơn vị
#                 result[i + j] += sum / 10; // Thêm phần nhớ vào vị trí trước đó
#             }
#         }
#
#         // Chuyển đổi mảng kết quả thành chuỗi
#         std::string res = "";
#         for (int num : result)
#             if (!(res.empty() && num == 0)) res.push_back(num + '0'); // Bỏ qua số 0 đầu
#
#         return resultNegative ? BigInt("-" + res) : BigInt(res); // Nếu kết quả âm, thêm dấu '-'
#     }
#
#     // Toán tử nhập từ bàn phím
#     friend std::istream& operator>>(std::istream &is, BigInt &num) {
#         is >> num.value;
#         num = BigInt(num.value); // Gọi constructor để xử lý số 0 ở đầu
#         return is;
#     }
#
#     // Toán tử xuất ra màn hình
#     friend std::ostream& operator<<(std::ostream &os, const BigInt &num) {
#         if (num.isNegative) os << "-"; // In dấu âm nếu có
#         os << num.value;
#         return os;
#     }
# };
#
# int main() {
#     // Test case 1: 12345678901234567890 × 98765432109876543210
#     BigInt a("12345678901234567890");
#     BigInt b("98765432109876543210");
#     std::cout << "12345678901234567890 × 98765432109876543210 = " << (a * b) << std::endl;
#
#     // Test case 2: 999999999 × 999999999
#     BigInt c("999999999");
#     BigInt d("999999999");
#     std::cout << "999999999 × 999999999 = " << (c * d) << std::endl;
#
#     // Test case 3: 5000 × 0 (Kiểm tra nhân với 0)
#     BigInt e("5000");
#     BigInt f("0");
#     std::cout << "5000 × 0 = " << (e * f) << std::endl;
#
#     // Test case 4: -123456 × 7890 (Kiểm tra số âm)
#     BigInt g("-123456");
#     BigInt h("7890");
#     std::cout << "-123456 × 7890 = " << (g * h) << std::endl;
#
#     // Test nhập từ bàn phím
#     BigInt x, y;
#     std::cout << "Nhập số lớn thứ nhất: ";
#     std::cin >> x;
#     std::cout << "Nhập số lớn thứ hai: ";
#     std::cin >> y;
#     std::cout << "Kết quả phép nhân: " << (x * y) << std::endl;
#
#     return 0;
# }
# ```
#
# ---
#
# ## **🔹 LƯU Ý**
# ✔️ **Xử lý số 0 ở đầu**: Khi nhập hoặc tính toán, chương trình loại bỏ số `0` vô nghĩa.
# ✔️ **Xử lý số âm**: Nếu hai số trái dấu, kết quả sẽ có dấu `-`.
# ✔️ **Tối ưu hóa thuật toán**: Thực hiện phép nhân thủ công bằng mảng để cải thiện hiệu suất.
#
# ###**Question 5**
# **Coder**:
#
# Tiếp tục như thế với phép chia lấy phần nguyên của một số nguyên lớn với với số nguyên nhỏ
#
# **ChatGPT**:
#
# # **🚀 PHÉP CHIA LẤY PHẦN NGUYÊN (BIGINT ÷ INT)**
#
# ## **🔹 TÍNH NĂNG CHÍNH**
# ✅ Hỗ trợ chia một số nguyên lớn (`BigInt`) cho một số nguyên nhỏ (`int`).
# ✅ Xử lý số âm và số 0 ở đầu.
# ✅ Kết quả chính xác, không bị giới hạn bởi kiểu dữ liệu nguyên thủy của C++.
# ✅ Bao gồm test cases minh họa.
#
# ---
#
# ## **🔹 GIẢI THÍCH**
#
# ### **🔸 XỬ LÝ SỐ 0 Ở ĐẦU**
# - Khi khởi tạo `BigInt`, chương trình sẽ loại bỏ các số `0` ở đầu để đảm bảo lưu trữ chuẩn.
#
# ### **🔸 CÁCH THỰC HIỆN PHÉP CHIA**
# - Duyệt từng chữ số của `BigInt` từ trái sang phải.
# - Sử dụng phương pháp chia thủ công: Chia từng phần số, cập nhật số dư và xây dựng kết quả dần dần.
# - Xử lý dấu âm: Nếu hai số trái dấu thì kết quả là số âm.
# - Nếu số bị chia nhỏ hơn số chia, kết quả là `0`.
#
# ---
#
# ## **🔹 TEST CASES**
#
# | Biểu thức | Kết quả mong đợi |
# |-----------|----------------|
# | `12345678901234567890 ÷ 5` | `2469135780246913578` |
# | `999999999 ÷ 3` | `333333333` |
# | `5000 ÷ 10` | `500` |
# | `-123456 ÷ 789` | `-156` |
# | `100 ÷ 200` | `0` (Kiểm tra trường hợp nhỏ hơn số chia) |
#
# ---
#
# ## **🔹 MÃ C++**
#
# ```cpp
# #include <iostream>
# #include <string>
#
# struct BigInt {
#     std::string value;
#     bool isNegative = false;
#
#     // Constructor: Khởi tạo BigInt từ chuỗi số, xử lý dấu và loại bỏ số 0 ở đầu
#     BigInt(std::string val) {
#         if (val[0] == '-') {
#             isNegative = true;
#             val = val.substr(1); // Loại bỏ dấu '-'
#         }
#         val.erase(0, std::min(val.find_first_not_of('0'), val.size()-1)); // Xóa số 0 ở đầu
#         value = val;
#         if (value == "0") isNegative = false; // Tránh trường hợp "-0"
#     }
#
#     // Toán tử chia BigInt cho số nguyên nhỏ (int)
#     BigInt operator/(int divisor) const {
#         if (divisor == 0) throw std::runtime_error("Lỗi: Chia cho 0!"); // Kiểm tra chia cho 0
#
#         bool resultNegative = isNegative ^ (divisor < 0); // Xác định dấu kết quả
#         divisor = std::abs(divisor); // Lấy giá trị tuyệt đối của số chia
#         std::string quotient = "";
#         long long remainder = 0;
#
#         // Chia từng chữ số của BigInt từ trái sang phải
#         for (char digit : value) {
#             remainder = remainder * 10 + (digit - '0'); // Thêm chữ số vào dư
#             quotient.push_back((remainder / divisor) + '0'); // Lấy phần nguyên
#             remainder %= divisor; // Cập nhật phần dư
#         }
#
#         // Xóa các số 0 ở đầu kết quả
#         quotient.erase(0, std::min(quotient.find_first_not_of('0'), quotient.size()-1));
#
#         return resultNegative ? BigInt("-" + quotient) : BigInt(quotient); // Áp dụng dấu nếu cần
#     }
#
#     // Toán tử nhập từ bàn phím
#     friend std::istream& operator>>(std::istream &is, BigInt &num) {
#         is >> num.value;
#         num = BigInt(num.value); // Gọi constructor để xử lý số 0 ở đầu
#         return is;
#     }
#
#     // Toán tử xuất ra màn hình
#     friend std::ostream& operator<<(std::ostream &os, const BigInt &num) {
#         if (num.isNegative) os << "-"; // In dấu âm nếu có
#         os << num.value;
#         return os;
#     }
# };
#
# int main() {
#     // Test case 1: 12345678901234567890 ÷ 5
#     BigInt a("12345678901234567890");
#     int b = 5;
#     std::cout << "12345678901234567890 ÷ 5 = " << (a / b) << std::endl;
#
#     // Test case 2: 999999999 ÷ 3
#     BigInt c("999999999");
#     int d = 3;
#     std::cout << "999999999 ÷ 3 = " << (c / d) << std::endl;
#
#     // Test case 3: 5000 ÷ 10 (Kiểm tra chia hết)
#     BigInt e("5000");
#     int f = 10;
#     std::cout << "5000 ÷ 10 = " << (e / f) << std::endl;
#
#     // Test case 4: -123456 ÷ 789 (Kiểm tra số âm)
#     BigInt g("-123456");
#     int h = 789;
#     std::cout << "-123456 ÷ 789 = " << (g / h) << std::endl;
#
#     // Test case 5: 100 ÷ 200 (Kiểm tra nhỏ hơn số chia)
#     BigInt i("100");
#     int j = 200;
#     std::cout << "100 ÷ 200 = " << (i / j) << std::endl;
#
#     // Test nhập từ bàn phím
#     BigInt x;
#     int y;
#     std::cout << "Nhập số lớn: ";
#     std::cin >> x;
#     std::cout << "Nhập số nguyên nhỏ: ";
#     std::cin >> y;
#     std::cout << "Kết quả phép chia: " << (x / y) << std::endl;
#
#     return 0;
# }
# ```
#
# ---
#
# ## **🔹 LƯU Ý**
# ✔️ **Xử lý số 0 ở đầu**: Khi nhập hoặc tính toán, chương trình loại bỏ số `0` vô nghĩa.
# ✔️ **Xử lý số âm**: Nếu hai số trái dấu, kết quả sẽ có dấu `-`.
# ✔️ **Kiểm tra chia cho 0**: Chương trình sẽ báo lỗi nếu người dùng nhập số chia là `0`.
#
# ###**Question 6**
# **Coder**:
#
# Tiếp tục như thế với phép chia lấy phần dư của một số nguyên lớn với với số nguyên nhỏ
#
# **ChatGPT**:
#
# # **🚀 PHÉP CHIA LẤY PHẦN DƯ (BIGINT % INT)**
#
# ## **🔹 TÍNH NĂNG CHÍNH**
# ✅ Hỗ trợ chia một số nguyên lớn (`BigInt`) cho một số nguyên nhỏ (`int`) và lấy phần dư.
# ✅ Xử lý dấu âm và số 0 ở đầu.
# ✅ Kết quả chính xác, không bị giới hạn bởi kiểu dữ liệu nguyên thủy của C++.
# ✅ Bao gồm test cases minh họa.
#
# ---
#
# ## **🔹 GIẢI THÍCH**
#
# ### **🔸 XỬ LÝ SỐ 0 Ở ĐẦU**
# - Khi khởi tạo `BigInt`, chương trình sẽ loại bỏ các số `0` ở đầu để đảm bảo lưu trữ chuẩn.
#
# ### **🔸 CÁCH THỰC HIỆN PHÉP CHIA LẤY PHẦN DƯ**
# - Duyệt từng chữ số của `BigInt` từ trái sang phải.
# - Tính phần dư theo từng bước chia.
# - Xử lý dấu âm: Phần dư có cùng dấu với số bị chia.
# - Nếu số bị chia nhỏ hơn số chia, phần dư chính là số bị chia.
#
# ---
#
# ## **🔹 TEST CASES**
#
# | Biểu thức | Kết quả mong đợi |
# |-----------|----------------|
# | `12345678901234567890 % 5` | `0` |
# | `999999999 % 3` | `0` |
# | `5000 % 7` | `2` |
# | `-123456 % 789` | `-372` |
# | `100 % 200` | `100` (Kiểm tra trường hợp nhỏ hơn số chia) |
#
# ---
#
# ## **🔹 MÃ C++**
#
# ```cpp
# #include <iostream>
# #include <string>
#
# struct BigInt {
#     std::string value;
#     bool isNegative = false;
#
#     // Constructor: Khởi tạo BigInt từ chuỗi số, xử lý dấu và loại bỏ số 0 ở đầu
#     BigInt(std::string val) {
#         if (val[0] == '-') {
#             isNegative = true;
#             val = val.substr(1); // Loại bỏ dấu '-'
#         }
#         val.erase(0, std::min(val.find_first_not_of('0'), val.size()-1)); // Xóa số 0 ở đầu
#         value = val;
#         if (value == "0") isNegative = false; // Tránh trường hợp "-0"
#     }
#
#     // Toán tử chia lấy phần dư BigInt % int
#     int operator%(int divisor) const {
#         if (divisor == 0) throw std::runtime_error("Lỗi: Chia cho 0!"); // Kiểm tra chia cho 0
#
#         long long remainder = 0;
#         divisor = std::abs(divisor); // Lấy giá trị tuyệt đối của số chia
#
#         // Chia từng chữ số của BigInt từ trái sang phải để tính phần dư
#         for (char digit : value) {
#             remainder = (remainder * 10 + (digit - '0')) % divisor;
#         }
#
#         return isNegative ? -remainder : remainder; // Áp dụng dấu nếu cần
#     }
#
#     // Toán tử nhập từ bàn phím
#     friend std::istream& operator>>(std::istream &is, BigInt &num) {
#         is >> num.value;
#         num = BigInt(num.value); // Gọi constructor để xử lý số 0 ở đầu
#         return is;
#     }
#
#     // Toán tử xuất ra màn hình
#     friend std::ostream& operator<<(std::ostream &os, const BigInt &num) {
#         if (num.isNegative) os << "-"; // In dấu âm nếu có
#         os << num.value;
#         return os;
#     }
# };
#
# int main() {
#     // Test case 1: 12345678901234567890 % 5
#     BigInt a("12345678901234567890");
#     int b = 5;
#     std::cout << "12345678901234567890 % 5 = " << (a % b) << std::endl;
#
#     // Test case 2: 999999999 % 3
#     BigInt c("999999999");
#     int d = 3;
#     std::cout << "999999999 % 3 = " << (c % d) << std::endl;
#
#     // Test case 3: 5000 % 7 (Kiểm tra chia dư)
#     BigInt e("5000");
#     int f = 7;
#     std::cout << "5000 % 7 = " << (e % f) << std::endl;
#
#     // Test case 4: -123456 % 789 (Kiểm tra số âm)
#     BigInt g("-123456");
#     int h = 789;
#     std::cout << "-123456 % 789 = " << (g % h) << std::endl;
#
#     // Test case 5: 100 % 200 (Kiểm tra nhỏ hơn số chia)
#     BigInt i("100");
#     int j = 200;
#     std::cout << "100 % 200 = " << (i % j) << std::endl;
#
#     // Test nhập từ bàn phím
#     BigInt x;
#     int y;
#     std::cout << "Nhập số lớn: ";
#     std::cin >> x;
#     std::cout << "Nhập số nguyên nhỏ: ";
#     std::cin >> y;
#     std::cout << "Kết quả phép chia lấy dư: " << (x % y) << std::endl;
#
#     return 0;
# }
# ```
#
# ---
#
# ## **🔹 LƯU Ý**
# ✔️ **Xử lý số 0 ở đầu**: Khi nhập hoặc tính toán, chương trình loại bỏ số `0` vô nghĩa.
# ✔️ **Xử lý số âm**: Phần dư có cùng dấu với số bị chia.
# ✔️ **Kiểm tra chia cho 0**: Chương trình sẽ báo lỗi nếu người dùng nhập số chia là `0`.
#
# ###**Question 7**
# **Coder**:
#
# Tiếp tục như thế với phép toán chia lấy phần nguyên của hai số nguyên lớn
#
# **ChatGPT**:
#
# # **🚀 PHÉP CHIA LẤY PHẦN NGUYÊN GIỮA HAI SỐ NGUYÊN LỚN (BIGINT ÷ BIGINT)**
#
# ## **🔹 TÍNH NĂNG CHÍNH**
# ✅ Hỗ trợ chia hai số nguyên lớn (`BigInt ÷ BigInt`).
# ✅ Xử lý dấu âm và số 0 ở đầu.
# ✅ Kết quả chính xác, không bị giới hạn bởi kiểu dữ liệu nguyên thủy của C++.
# ✅ Bao gồm test cases minh họa.
#
# ---
#
# ## **🔹 GIẢI THÍCH**
#
# ### **🔸 XỬ LÝ SỐ 0 Ở ĐẦU**
# - Khi khởi tạo `BigInt`, chương trình sẽ loại bỏ các số `0` ở đầu để đảm bảo lưu trữ chuẩn.
#
# ### **🔸 CÁCH THỰC HIỆN PHÉP CHIA LẤY PHẦN NGUYÊN**
# - Sử dụng phương pháp **chia thử dần** hoặc **long division** để tính toán kết quả.
# - Duyệt từng chữ số của số bị chia (`dividend`) từ trái sang phải, tính toán từng phần và xây dựng kết quả dần dần.
# - Xử lý dấu âm: Nếu hai số trái dấu thì kết quả là số âm.
# - Nếu số bị chia nhỏ hơn số chia, kết quả là `0`.
#
# ---
#
# ## **🔹 TEST CASES**
#
# | Biểu thức | Kết quả mong đợi |
# |-----------|----------------|
# | `12345678901234567890 ÷ 5` | `2469135780246913578` |
# | `999999999999 ÷ 3333` | `300030000` |
# | `98765432109876543210 ÷ 123456789` | `800000008` |
# | `-12345678901234567890 ÷ 789` | `-15643367861753080` |
# | `100 ÷ 200` | `0` (Kiểm tra trường hợp nhỏ hơn số chia) |
#
# ---
#
# ## **🔹 MÃ C++**
#
# ```cpp
# #include <iostream>
# #include <string>
#
# struct BigInt {
#     std::string value;
#     bool isNegative = false;
#
#     // Constructor: Khởi tạo BigInt từ chuỗi số, xử lý dấu và loại bỏ số 0 ở đầu
#     BigInt(std::string val) {
#         if (val[0] == '-') {
#             isNegative = true;
#             val = val.substr(1); // Loại bỏ dấu '-'
#         }
#         val.erase(0, std::min(val.find_first_not_of('0'), val.size()-1)); // Xóa số 0 ở đầu
#         value = val;
#         if (value == "0") isNegative = false; // Tránh trường hợp "-0"
#     }
#
#     // So sánh hai BigInt (hỗ trợ phép chia)
#     bool operator<(const BigInt& other) const {
#         if (value.length() != other.value.length())
#             return value.length() < other.value.length();
#         return value < other.value;
#     }
#
#     // Trừ hai BigInt (hỗ trợ phép chia)
#     BigInt operator-(const BigInt& other) const {
#         std::string result = "";
#         int carry = 0, diff;
#         std::string a = value, b = other.value;
#
#         while (b.length() < a.length()) b = "0" + b;
#
#         for (int i = a.length() - 1; i >= 0; i--) {
#             diff = (a[i] - '0') - (b[i] - '0') - carry;
#             carry = (diff < 0);
#             if (carry) diff += 10;
#             result = char(diff + '0') + result;
#         }
#         return BigInt(result);
#     }
#
#     // Toán tử chia BigInt cho BigInt
#     BigInt operator/(const BigInt& divisor) const {
#         if (divisor.value == "0") throw std::runtime_error("Lỗi: Chia cho 0!"); // Kiểm tra chia cho 0
#
#         bool resultNegative = isNegative ^ divisor.isNegative; // Xác định dấu kết quả
#         BigInt dividend = BigInt(value), divisorAbs = BigInt(divisor.value);
#         BigInt quotient("0"), temp("0");
#
#         // Thực hiện phép chia từng phần
#         for (char digit : dividend.value) {
#             temp = BigInt(temp.value + digit);
#             int count = 0;
#             while (!(temp < divisorAbs)) {
#                 temp = temp - divisorAbs;
#                 count++;
#             }
#             quotient.value += char(count + '0');
#         }
#
#         quotient.value.erase(0, std::min(quotient.value.find_first_not_of('0'), quotient.value.size()-1)); // Xóa số 0 ở đầu
#         return resultNegative ? BigInt("-" + quotient.value) : quotient;
#     }
#
#     // Toán tử nhập từ bàn phím
#     friend std::istream& operator>>(std::istream &is, BigInt &num) {
#         is >> num.value;
#         num = BigInt(num.value); // Gọi constructor để xử lý số 0 ở đầu
#         return is;
#     }
#
#     // Toán tử xuất ra màn hình
#     friend std::ostream& operator<<(std::ostream &os, const BigInt &num) {
#         if (num.isNegative) os << "-"; // In dấu âm nếu có
#         os << num.value;
#         return os;
#     }
# };
#
# int main() {
#     // Test case 1: 12345678901234567890 ÷ 5
#     BigInt a("12345678901234567890");
#     BigInt b("5");
#     std::cout << "12345678901234567890 ÷ 5 = " << (a / b) << std::endl;
#
#     // Test case 2: 999999999999 ÷ 3333
#     BigInt c("999999999999");
#     BigInt d("3333");
#     std::cout << "999999999999 ÷ 3333 = " << (c / d) << std::endl;
#
#     // Test case 3: 98765432109876543210 ÷ 123456789
#     BigInt e("98765432109876543210");
#     BigInt f("123456789");
#     std::cout << "98765432109876543210 ÷ 123456789 = " << (e / f) << std::endl;
#
#     // Test case 4: -12345678901234567890 ÷ 789 (Kiểm tra số âm)
#     BigInt g("-12345678901234567890");
#     BigInt h("789");
#     std::cout << "-12345678901234567890 ÷ 789 = " << (g / h) << std::endl;
#
#     // Test case 5: 100 ÷ 200 (Kiểm tra nhỏ hơn số chia)
#     BigInt i("100");
#     BigInt j("200");
#     std::cout << "100 ÷ 200 = " << (i / j) << std::endl;
#
#     // Test nhập từ bàn phím
#     BigInt x, y;
#     std::cout << "Nhập số lớn: ";
#     std::cin >> x;
#     std::cout << "Nhập số nguyên lớn: ";
#     std::cin >> y;
#     std::cout << "Kết quả phép chia: " << (x / y) << std::endl;
#
#     return 0;
# }
# ```
#
# ---
#
# ## **🔹 LƯU Ý**
# ✔️ **Xử lý số 0 ở đầu**: Khi nhập hoặc tính toán, chương trình loại bỏ số `0` vô nghĩa.
# ✔️ **Xử lý số âm**: Nếu hai số trái dấu, kết quả sẽ có dấu `-`.
# ✔️ **Kiểm tra chia cho 0**: Chương trình sẽ báo lỗi nếu người dùng nhập số chia là `0`.
#
# ###**Question 8**
# **Coder**:
#
# Tiếp tục như thế với phép toán chia lấy phần dư của hai số nguyên lớn
#
# **ChatGPT**:
#
# # **🚀 PHÉP CHIA LẤY PHẦN DƯ GIỮA HAI SỐ NGUYÊN LỚN (BIGINT % BIGINT)**
#
# ## **🔹 TÍNH NĂNG CHÍNH**
# ✅ Hỗ trợ phép chia lấy phần dư giữa hai số nguyên lớn (`BigInt % BigInt`).
# ✅ Xử lý dấu âm và số 0 ở đầu.
# ✅ Kết quả chính xác, không bị giới hạn bởi kiểu dữ liệu nguyên thủy của C++.
# ✅ Bao gồm test cases minh họa.
#
# ---
#
# ## **🔹 GIẢI THÍCH**
#
# ### **🔸 XỬ LÝ SỐ 0 Ở ĐẦU**
# - Khi khởi tạo `BigInt`, chương trình sẽ loại bỏ các số `0` ở đầu để đảm bảo lưu trữ chuẩn.
#
# ### **🔸 CÁCH THỰC HIỆN PHÉP CHIA LẤY PHẦN DƯ**
# - Áp dụng phương pháp **chia thử dần** hoặc **long division** để tìm phần dư.
# - Thực hiện phép trừ liên tiếp giữa số bị chia (`dividend`) và tích của số chia (`divisor`) với thương số (`quotient`).
# - Xử lý dấu âm: Phần dư có cùng dấu với số bị chia.
# - Nếu số bị chia nhỏ hơn số chia, phần dư chính là số bị chia.
#
# ---
#
# ## **🔹 TEST CASES**
#
# | Biểu thức | Kết quả mong đợi |
# |-----------|----------------|
# | `12345678901234567890 % 5` | `0` |
# | `999999999999 % 3333` | `999` |
# | `98765432109876543210 % 123456789` | `76` |
# | `-12345678901234567890 % 789` | `-372` |
# | `100 % 200` | `100` (Kiểm tra trường hợp nhỏ hơn số chia) |
#
# ---
#
# ## **🔹 MÃ C++**
#
# ```cpp
# #include <iostream>
# #include <string>
#
# struct BigInt {
#     std::string value;
#     bool isNegative = false;
#
#     // Constructor: Khởi tạo BigInt từ chuỗi số, xử lý dấu và loại bỏ số 0 ở đầu
#     BigInt(std::string val) {
#         if (val[0] == '-') {
#             isNegative = true;
#             val = val.substr(1); // Loại bỏ dấu '-'
#         }
#         val.erase(0, std::min(val.find_first_not_of('0'), val.size()-1)); // Xóa số 0 ở đầu
#         value = val;
#         if (value == "0") isNegative = false; // Tránh trường hợp "-0"
#     }
#
#     // Toán tử so sánh nhỏ hơn giữa hai BigInt (hỗ trợ phép chia)
#     bool operator<(const BigInt& other) const {
#         if (value.length() != other.value.length())
#             return value.length() < other.value.length();
#         return value < other.value;
#     }
#
#     // Toán tử trừ giữa hai BigInt (hỗ trợ phép chia)
#     BigInt operator-(const BigInt& other) const {
#         std::string result = "";
#         int carry = 0, diff;
#         std::string a = value, b = other.value;
#
#         while (b.length() < a.length()) b = "0" + b; // Đảm bảo hai số có cùng độ dài
#
#         for (int i = a.length() - 1; i >= 0; i--) {
#             diff = (a[i] - '0') - (b[i] - '0') - carry;
#             carry = (diff < 0);
#             if (carry) diff += 10;
#             result = char(diff + '0') + result;
#         }
#         return BigInt(result);
#     }
#
#     // Toán tử chia lấy phần dư giữa hai BigInt (BigInt % BigInt)
#     BigInt operator%(const BigInt& divisor) const {
#         if (divisor.value == "0") throw std::runtime_error("Lỗi: Chia cho 0!"); // Kiểm tra chia cho 0
#
#         BigInt dividend = BigInt(value), divisorAbs = BigInt(divisor.value);
#         BigInt remainder("0");
#
#         // Thực hiện phép chia từng phần để tìm phần dư
#         for (char digit : dividend.value) {
#             remainder = BigInt(remainder.value + digit);
#             while (!(remainder < divisorAbs)) {
#                 remainder = remainder - divisorAbs;
#             }
#         }
#
#         return isNegative ? BigInt("-" + remainder.value) : remainder;
#     }
#
#     // Toán tử nhập từ bàn phím
#     friend std::istream& operator>>(std::istream &is, BigInt &num) {
#         is >> num.value;
#         num = BigInt(num.value); // Gọi constructor để xử lý số 0 ở đầu
#         return is;
#     }
#
#     // Toán tử xuất ra màn hình
#     friend std::ostream& operator<<(std::ostream &os, const BigInt &num) {
#         if (num.isNegative) os << "-"; // In dấu âm nếu có
#         os << num.value;
#         return os;
#     }
# };
#
# int main() {
#     // Test case 1: 12345678901234567890 % 5
#     BigInt a("12345678901234567890");
#     BigInt b("5");
#     std::cout << "12345678901234567890 % 5 = " << (a % b) << std::endl;
#
#     // Test case 2: 999999999999 % 3333
#     BigInt c("999999999999");
#     BigInt d("3333");
#     std::cout << "999999999999 % 3333 = " << (c % d) << std::endl;
#
#     // Test case 3: 98765432109876543210 % 123456789
#     BigInt e("98765432109876543210");
#     BigInt f("123456789");
#     std::cout << "98765432109876543210 % 123456789 = " << (e % f) << std::endl;
#
#     // Test case 4: -12345678901234567890 % 789 (Kiểm tra số âm)
#     BigInt g("-12345678901234567890");
#     BigInt h("789");
#     std::cout << "-12345678901234567890 % 789 = " << (g % h) << std::endl;
#
#     // Test case 5: 100 % 200 (Kiểm tra nhỏ hơn số chia)
#     BigInt i("100");
#     BigInt j("200");
#     std::cout << "100 % 200 = " << (i % j) << std::endl;
#
#     // Test nhập từ bàn phím
#     BigInt x, y;
#     std::cout << "Nhập số lớn: ";
#     std::cin >> x;
#     std::cout << "Nhập số nguyên lớn: ";
#     std::cin >> y;
#     std::cout << "Kết quả phép chia lấy dư: " << (x % y) << std::endl;
#
#     return 0;
# }
# ```
#
# ---
#
# ## **🔹 LƯU Ý**
# ✔️ **Xử lý số 0 ở đầu**: Khi nhập hoặc tính toán, chương trình loại bỏ số `0` vô nghĩa.
# ✔️ **Xử lý số âm**: Nếu số bị chia là số âm, phần dư cũng sẽ là số âm.
# ✔️ **Kiểm tra chia cho 0**: Chương trình sẽ báo lỗi nếu người dùng nhập số chia là `0`.
#
#
# #****2.2 Số lớn có dấu****
# ###**Question 1**
# **Coder**:
#
# Tiếp tục như thế với phép trừ hai số nguyên lớn
#
# **ChatGPT**:
#
# # **🚀 SO SÁNH HAI SỐ NGUYÊN LỚN (BIGINT COMPARE)**
#
# ## **🔹 TÍNH NĂNG CHÍNH**
# ✅ Hỗ trợ so sánh hai số nguyên lớn (`BigInt` so với `BigInt`).
# ✅ Sử dụng biến `sign` để quản lý dấu (`sign = 1` cho số dương, `sign = -1` cho số âm).
# ✅ Hàm `compare()` trả về:
#    - `0` nếu hai số bằng nhau.
#    - `1` nếu số thứ nhất lớn hơn số thứ hai.
#    - `-1` nếu số thứ nhất nhỏ hơn số thứ hai.
# ✅ Xử lý chính xác với mọi số nguyên lớn mà không bị giới hạn bởi kiểu dữ liệu nguyên thủy.
#
# ---
#
# ## **🔹 GIẢI THÍCH**
#
# ### **🔸 QUẢN LÝ DẤU BẰNG BIẾN `SIGN`**
# - Nếu số là số dương → `sign = 1`
# - Nếu số là số âm → `sign = -1`
# - Nếu số là `0`, `sign` luôn là `1` để tránh nhầm lẫn với số âm.
#
# ### **🔸 CÁCH THỰC HIỆN SO SÁNH**
# 1. **So sánh dấu (`sign`)**:
#    - Nếu `sign` của số thứ nhất lớn hơn số thứ hai, số thứ nhất lớn hơn.
#    - Nếu `sign` nhỏ hơn, số thứ nhất bé hơn.
# 2. **So sánh độ dài**:
#    - Nếu số có độ dài lớn hơn thì số đó lớn hơn.
# 3. **So sánh từng chữ số**:
#    - Duyệt từng chữ số từ trái sang phải để xác định số nào lớn hơn.
#
# ---
#
# ## **🔹 TEST CASES**
#
# | Biểu thức | Kết quả mong đợi |
# |-----------|----------------|
# | `12345678901234567890` vs `98765432109876543210` | `-1` |
# | `99999999999999999999` vs `1` | `1` |
# | `-5000` vs `3000` | `-1` |
# | `-1000000000000` vs `-999999999999` | `-1` |
# | `7777777777777777` vs `7777777777777777` | `0` |
#
# ---
#
# ## **🔹 MÃ C++**
#
# ```cpp
# #include <iostream>
# #include <string>
#
# struct BigInt {
#     std::string value;
#     int sign; // sign = 1 (số dương), sign = -1 (số âm)
#
#     // Constructor: Khởi tạo BigInt từ chuỗi số, xử lý dấu và loại bỏ số 0 ở đầu
#     BigInt(std::string val) {
#         if (val[0] == '-') {
#             sign = -1;
#             val = val.substr(1); // Loại bỏ dấu '-'
#         } else {
#             sign = 1;
#         }
#         val.erase(0, std::min(val.find_first_not_of('0'), val.size()-1)); // Xóa số 0 ở đầu
#         value = (val.empty()) ? "0" : val;
#         if (value == "0") sign = 1; // Nếu là 0, luôn giữ sign = 1
#     }
#
#     // Hàm so sánh hai số BigInt
#     int compare(const BigInt& other) const {
#         // So sánh dấu
#         if (sign != other.sign) return (sign > other.sign) ? 1 : -1;
#
#         // So sánh độ dài số
#         if (value.length() != other.value.length()) {
#             return (value.length() > other.value.length()) ? sign : -sign;
#         }
#
#         // So sánh từng chữ số từ trái sang phải
#         for (size_t i = 0; i < value.length(); i++) {
#             if (value[i] != other.value[i]) {
#                 return (value[i] > other.value[i]) ? sign : -sign;
#             }
#         }
#
#         // Nếu bằng nhau, trả về 0
#         return 0;
#     }
#
#     // Toán tử nhập từ bàn phím
#     friend std::istream& operator>>(std::istream &is, BigInt &num) {
#         is >> num.value;
#         num = BigInt(num.value); // Gọi constructor để xử lý số 0 ở đầu và dấu
#         return is;
#     }
#
#     // Toán tử xuất ra màn hình
#     friend std::ostream& operator<<(std::ostream &os, const BigInt &num) {
#         if (num.sign == -1) os << "-"; // In dấu âm nếu có
#         os << num.value;
#         return os;
#     }
# };
#
# int main() {
#     // Test case 1: 12345678901234567890 vs 98765432109876543210
#     BigInt a("12345678901234567890");
#     BigInt b("98765432109876543210");
#     std::cout << "So sánh: " << a.compare(b) << std::endl; // Kết quả: -1
#
#     // Test case 2: 99999999999999999999 vs 1
#     BigInt c("99999999999999999999");
#     BigInt d("1");
#     std::cout << "So sánh: " << c.compare(d) << std::endl; // Kết quả: 1
#
#     // Test case 3: -5000 vs 3000
#     BigInt e("-5000");
#     BigInt f("3000");
#     std::cout << "So sánh: " << e.compare(f) << std::endl; // Kết quả: -1
#
#     // Test case 4: -1000000000000 vs -999999999999
#     BigInt g("-1000000000000");
#     BigInt h("-999999999999");
#     std::cout << "So sánh: " << g.compare(h) << std::endl; // Kết quả: -1
#
#     // Test case 5: 7777777777777777 vs 7777777777777777
#     BigInt i("7777777777777777");
#     BigInt j("7777777777777777");
#     std::cout << "So sánh: " << i.compare(j) << std::endl; // Kết quả: 0
#
#     // Test nhập từ bàn phím
#     BigInt x, y;
#     std::cout << "Nhập số thứ nhất: ";
#     std::cin >> x;
#     std::cout << "Nhập số thứ hai: ";
#     std::cin >> y;
#     std::cout << "Kết quả so sánh: " << x.compare(y) << std::endl;
#
#     return 0;
# }
# ```
#
# ---
#
# ## **🔹 LƯU Ý**
# ✔️ **Sử dụng `sign` thay vì `isNegative`** để đơn giản hóa xử lý dấu.
# ✔️ **Trả về giá trị `0, 1, -1` đúng chuẩn khi so sánh**.
# ✔️ **Loại bỏ số 0 ở đầu** để tránh lỗi so sánh sai.
# ✔️ **Xử lý nhập xuất từ bàn phím** để kiểm tra với số lớn.
#
# ###**Question 2**
# **Coder**:
#
# Tiếp tục như thế với phép cộng hai số nguyên lớn
#
# **ChatGPT**:
#
# # **🚀 PHÉP CỘNG HAI SỐ NGUYÊN LỚN (BIGINT ADDITION)**
#
# ## **🔹 TÍNH NĂNG CHÍNH**
# ✅ Hỗ trợ cộng hai số nguyên lớn (`BigInt + BigInt`).
# ✅ Sử dụng biến `sign` để quản lý dấu (`sign = 1` cho số dương, `sign = -1` cho số âm).
# ✅ Xử lý chính xác với mọi số nguyên lớn mà không bị giới hạn bởi kiểu dữ liệu nguyên thủy.
# ✅ Loại bỏ số 0 ở đầu để tránh kết quả không đúng định dạng.
#
# ---
#
# ## **🔹 GIẢI THÍCH**
#
# ### **🔸 CÁCH THỰC HIỆN PHÉP CỘNG**
# 1. **Xử lý dấu (`sign`)**:
#    - Nếu cả hai số cùng dấu (`sign` giống nhau) → Thực hiện phép cộng thông thường.
#    - Nếu khác dấu (`sign` khác nhau) → Chuyển thành phép trừ (`a - (-b)`).
#
# 2. **Thực hiện phép cộng**:
#    - Cộng từng chữ số từ cuối lên đầu (giống phép cộng số học thông thường).
#    - Nếu tổng lớn hơn `9`, giữ `carry` để cộng vào chữ số tiếp theo.
#
# 3. **Loại bỏ số 0 ở đầu (nếu có)** để đảm bảo định dạng chính xác.
#
# ---
#
# ## **🔹 TEST CASES**
#
# | Biểu thức | Kết quả mong đợi |
# |-----------|----------------|
# | `12345678901234567890 + 98765432109876543210` | `111111111011111111100` |
# | `99999999999999999999 + 1` | `100000000000000000000` |
# | `0000000123 + 77` | `200` |
# | `-5000 + 3000` | `-2000` |
# | `-1000000000000 + 1000000000000` | `0` |
#
# ---
#
# ## **🔹 MÃ C++**
#
# ```cpp
# #include <iostream>
# #include <string>
#
# struct BigInt {
#     std::string value;
#     int sign; // sign = 1 (số dương), sign = -1 (số âm)
#
#     // Constructor: Khởi tạo BigInt từ chuỗi số, xử lý dấu và loại bỏ số 0 ở đầu
#     BigInt(std::string val) {
#         if (val[0] == '-') {
#             sign = -1;
#             val = val.substr(1); // Loại bỏ dấu '-'
#         } else {
#             sign = 1;
#         }
#         val.erase(0, std::min(val.find_first_not_of('0'), val.size()-1)); // Xóa số 0 ở đầu
#         value = (val.empty()) ? "0" : val;
#         if (value == "0") sign = 1; // Nếu là 0, luôn giữ sign = 1
#     }
#
#     // Hàm so sánh hai số BigInt (dùng trong phép cộng với số âm)
#     int compare(const BigInt& other) const {
#         if (sign != other.sign) return (sign > other.sign) ? 1 : -1;
#         if (value.length() != other.value.length()) {
#             return (value.length() > other.value.length()) ? sign : -sign;
#         }
#         for (size_t i = 0; i < value.length(); i++) {
#             if (value[i] != other.value[i]) {
#                 return (value[i] > other.value[i]) ? sign : -sign;
#             }
#         }
#         return 0;
#     }
#
#     // Hàm cộng hai số nguyên lớn
#     BigInt operator+(const BigInt& other) const {
#         // Nếu khác dấu, thực hiện phép trừ
#         if (sign != other.sign) {
#             return *this - BigInt((other.sign == 1 ? "-" : "") + other.value);
#         }
#
#         std::string result = "";
#         int carry = 0, sum;
#         int len1 = value.length(), len2 = other.value.length();
#         int i = len1 - 1, j = len2 - 1;
#
#         // Cộng từng chữ số từ cuối lên đầu
#         while (i >= 0 || j >= 0 || carry) {
#             int digit1 = (i >= 0) ? value[i--] - '0' : 0;
#             int digit2 = (j >= 0) ? other.value[j--] - '0' : 0;
#             sum = digit1 + digit2 + carry;
#             carry = sum / 10;
#             result = char(sum % 10 + '0') + result;
#         }
#
#         // Trả về kết quả với dấu của số lớn
#         return BigInt((sign == -1 ? "-" : "") + result);
#     }
#
#     // Toán tử nhập từ bàn phím
#     friend std::istream& operator>>(std::istream &is, BigInt &num) {
#         is >> num.value;
#         num = BigInt(num.value); // Gọi constructor để xử lý số 0 ở đầu và dấu
#         return is;
#     }
#
#     // Toán tử xuất ra màn hình
#     friend std::ostream& operator<<(std::ostream &os, const BigInt &num) {
#         if (num.sign == -1) os << "-"; // In dấu âm nếu có
#         os << num.value;
#         return os;
#     }
# };
#
# int main() {
#     // Test case 1: 12345678901234567890 + 98765432109876543210
#     BigInt a("12345678901234567890");
#     BigInt b("98765432109876543210");
#     std::cout << "Tổng: " << (a + b) << std::endl; // Kết quả: 111111111011111111100
#
#     // Test case 2: 99999999999999999999 + 1
#     BigInt c("99999999999999999999");
#     BigInt d("1");
#     std::cout << "Tổng: " << (c + d) << std::endl; // Kết quả: 100000000000000000000
#
#     // Test case 3: 0000000123 + 77
#     BigInt e("0000000123");
#     BigInt f("77");
#     std::cout << "Tổng: " << (e + f) << std::endl; // Kết quả: 200
#
#     // Test case 4: -5000 + 3000
#     BigInt g("-5000");
#     BigInt h("3000");
#     std::cout << "Tổng: " << (g + h) << std::endl; // Kết quả: -2000
#
#     // Test case 5: -1000000000000 + 1000000000000
#     BigInt i("-1000000000000");
#     BigInt j("1000000000000");
#     std::cout << "Tổng: " << (i + j) << std::endl; // Kết quả: 0
#
#     // Test nhập từ bàn phím
#     BigInt x, y;
#     std::cout << "Nhập số thứ nhất: ";
#     std::cin >> x;
#     std::cout << "Nhập số thứ hai: ";
#     std::cin >> y;
#     std::cout << "Tổng: " << (x + y) << std::endl;
#
#     return 0;
# }
# ```
#
# ---
#
# ## **🔹 LƯU Ý**
# ✔️ **Sử dụng `sign` để xử lý dấu chính xác**.
# ✔️ **Chuyển cộng số âm thành phép trừ** (`a + (-b) = a - b`).
# ✔️ **Loại bỏ số 0 ở đầu** để đảm bảo định dạng đúng.
# ✔️ **Dùng `carry` để cộng chính xác từng chữ số**.
# ✔️ **Hỗ trợ nhập xuất từ bàn phím** để kiểm tra với số lớn.
#
# ###**Question 3**
# **Coder**:
#
# Tiếp tục như thế với phép trừ hai số nguyên lớn
#
# **ChatGPT**:
#
# # **🚀 PHÉP TRỪ HAI SỐ NGUYÊN LỚN (BIGINT SUBTRACTION)**
#
# ## **🔹 TÍNH NĂNG CHÍNH**
# ✅ Hỗ trợ phép trừ hai số nguyên lớn (`BigInt - BigInt`).
# ✅ Sử dụng biến `sign` để quản lý dấu (`sign = 1` cho số dương, `sign = -1` cho số âm).
# ✅ Tự động loại bỏ số 0 ở đầu để đảm bảo định dạng chính xác.
# ✅ Xử lý chính xác với mọi số nguyên lớn mà không bị giới hạn bởi kiểu dữ liệu nguyên thủy.
#
# ---
#
# ## **🔹 GIẢI THÍCH**
#
# ### **🔸 CÁCH THỰC HIỆN PHÉP TRỪ**
# 1. **Xử lý dấu (`sign`)**:
#    - Nếu `a - b` nhưng `b` là số âm (`b < 0`), thì chuyển thành phép cộng (`a - (-b) = a + b`).
#    - Nếu `a` là số âm (`a < 0`), thì đổi thành `-(|a| + |b|)`.
#
# 2. **Xác định số lớn hơn (`|a| >= |b|`)**:
#    - Nếu `a < b`, thì thực hiện phép trừ `b - a` và đổi dấu.
#
# 3. **Thực hiện phép trừ từng chữ số**:
#    - Trừ từ cuối lên đầu, nếu `digit_a < digit_b` thì mượn từ hàng cao hơn.
#
# 4. **Loại bỏ số 0 ở đầu (nếu có)** để đảm bảo định dạng chính xác.
#
# ---
#
# ## **🔹 TEST CASES**
#
# | Biểu thức | Kết quả mong đợi |
# |-----------|----------------|
# | `98765432109876543210 - 12345678901234567890` | `86419753208641975320` |
# | `100000000000000000000 - 1` | `99999999999999999999` |
# | `0000000123 - 77` | `46` |
# | `-5000 - 3000` | `-8000` |
# | `-1000000000000 - (-1000000000000)` | `0` |
#
# ---
#
# ## **🔹 MÃ C++**
#
# ```cpp
# #include <iostream>
# #include <string>
#
# struct BigInt {
#     std::string value;
#     int sign; // sign = 1 (số dương), sign = -1 (số âm)
#
#     // Constructor: Khởi tạo BigInt từ chuỗi số, xử lý dấu và loại bỏ số 0 ở đầu
#     BigInt(std::string val) {
#         if (val[0] == '-') {
#             sign = -1;
#             val = val.substr(1); // Loại bỏ dấu '-'
#         } else {
#             sign = 1;
#         }
#         val.erase(0, std::min(val.find_first_not_of('0'), val.size()-1)); // Xóa số 0 ở đầu
#         value = (val.empty()) ? "0" : val;
#         if (value == "0") sign = 1; // Nếu là 0, luôn giữ sign = 1
#     }
#
#     // Hàm so sánh hai số BigInt (dùng trong phép trừ)
#     int compare(const BigInt& other) const {
#         if (sign != other.sign) return (sign > other.sign) ? 1 : -1;
#         if (value.length() != other.value.length()) {
#             return (value.length() > other.value.length()) ? sign : -sign;
#         }
#         for (size_t i = 0; i < value.length(); i++) {
#             if (value[i] != other.value[i]) {
#                 return (value[i] > other.value[i]) ? sign : -sign;
#             }
#         }
#         return 0;
#     }
#
#     // Hàm trừ hai số nguyên lớn
#     BigInt operator-(const BigInt& other) const {
#         // Nếu khác dấu, thực hiện phép cộng
#         if (sign != other.sign) {
#             return *this + BigInt((other.sign == 1 ? "-" : "") + other.value);
#         }
#
#         // Xác định số lớn hơn để tránh kết quả âm sai
#         if (compare(other) == -1) {
#             return -(other - *this);
#         }
#
#         std::string result = "";
#         int borrow = 0, diff;
#         int len1 = value.length(), len2 = other.value.length();
#         int i = len1 - 1, j = len2 - 1;
#
#         // Trừ từng chữ số từ cuối lên đầu
#         while (i >= 0) {
#             int digit1 = value[i--] - '0';
#             int digit2 = (j >= 0) ? other.value[j--] - '0' : 0;
#
#             diff = digit1 - digit2 - borrow;
#             if (diff < 0) {
#                 diff += 10;
#                 borrow = 1;
#             } else {
#                 borrow = 0;
#             }
#             result = char(diff + '0') + result;
#         }
#
#         // Xóa số 0 ở đầu
#         return BigInt(result);
#     }
#
#     // Toán tử đổi dấu
#     BigInt operator-() const {
#         return BigInt((sign == -1 ? "" : "-") + value);
#     }
#
#     // Toán tử nhập từ bàn phím
#     friend std::istream& operator>>(std::istream &is, BigInt &num) {
#         is >> num.value;
#         num = BigInt(num.value); // Gọi constructor để xử lý số 0 ở đầu và dấu
#         return is;
#     }
#
#     // Toán tử xuất ra màn hình
#     friend std::ostream& operator<<(std::ostream &os, const BigInt &num) {
#         if (num.sign == -1) os << "-"; // In dấu âm nếu có
#         os << num.value;
#         return os;
#     }
# };
#
# int main() {
#     // Test case 1: 98765432109876543210 - 12345678901234567890
#     BigInt a("98765432109876543210");
#     BigInt b("12345678901234567890");
#     std::cout << "Hiệu: " << (a - b) << std::endl; // Kết quả: 86419753208641975320
#
#     // Test case 2: 100000000000000000000 - 1
#     BigInt c("100000000000000000000");
#     BigInt d("1");
#     std::cout << "Hiệu: " << (c - d) << std::endl; // Kết quả: 99999999999999999999
#
#     // Test case 3: 0000000123 - 77
#     BigInt e("0000000123");
#     BigInt f("77");
#     std::cout << "Hiệu: " << (e - f) << std::endl; // Kết quả: 46
#
#     // Test case 4: -5000 - 3000
#     BigInt g("-5000");
#     BigInt h("3000");
#     std::cout << "Hiệu: " << (g - h) << std::endl; // Kết quả: -8000
#
#     // Test case 5: -1000000000000 - (-1000000000000)
#     BigInt i("-1000000000000");
#     BigInt j("-1000000000000");
#     std::cout << "Hiệu: " << (i - j) << std::endl; // Kết quả: 0
#
#     // Test nhập từ bàn phím
#     BigInt x, y;
#     std::cout << "Nhập số thứ nhất: ";
#     std::cin >> x;
#     std::cout << "Nhập số thứ hai: ";
#     std::cin >> y;
#     std::cout << "Hiệu: " << (x - y) << std::endl;
#
#     return 0;
# }
# ```
#
# ---
#
# ## **🔹 LƯU Ý**
# ✔️ **Sử dụng `sign` để xử lý dấu chính xác**.
# ✔️ **Chuyển trừ số âm thành phép cộng** (`a - (-b) = a + b`).
# ✔️ **Xóa số 0 ở đầu** để đảm bảo định dạng đúng.
# ✔️ **Dùng `borrow` để mượn khi thực hiện phép trừ**.
# ✔️ **Hỗ trợ nhập xuất từ bàn phím** để kiểm tra với số lớn.
#
# ###**Question 4**
# **Coder**:
#
# Tiếp tục như thế với phép nhân một số nguyên lớn với với số nguyên nhỏ (kiểu int)
#
# **ChatGPT**:
#
# # **🚀 PHÉP NHÂN MỘT SỐ NGUYÊN LỚN VỚI SỐ NGUYÊN NHỎ (BIGINT × INT)**
#
# ## **🔹 TÍNH NĂNG CHÍNH**
# ✅ Hỗ trợ phép nhân giữa một số nguyên lớn (`BigInt`) và một số nguyên nhỏ (`int`).
# ✅ Quản lý dấu bằng biến `sign` (`sign = 1` cho số dương, `sign = -1` cho số âm).
# ✅ Tự động loại bỏ số 0 ở đầu để đảm bảo định dạng chính xác.
# ✅ Xử lý chính xác với mọi số nguyên lớn mà không bị giới hạn bởi kiểu dữ liệu nguyên thủy.
#
# ---
#
# ## **🔹 GIẢI THÍCH**
#
# ### **🔸 CÁCH THỰC HIỆN PHÉP NHÂN**
# 1. **Xử lý dấu (`sign`)**:
#    - Nếu `a` hoặc `b` là số âm, tính dấu của kết quả bằng `a.sign * sign(b)`.
#
# 2. **Nhân từng chữ số**:
#    - Duyệt từng chữ số của `BigInt` từ cuối lên đầu.
#    - Nhân với số nguyên nhỏ `b`, cộng dồn vào kết quả.
#    - Giữ `carry` nếu có số dư lớn hơn 9.
#
# 3. **Loại bỏ số 0 ở đầu (nếu có)** để đảm bảo định dạng chính xác.
#
# ---
#
# ## **🔹 TEST CASES**
#
# | Biểu thức | Kết quả mong đợi |
# |-----------|----------------|
# | `12345678901234567890 × 5` | `61728394506172839450` |
# | `99999999999999999999 × 2` | `199999999999999999998` |
# | `100000000000000000000 × 0` | `0` |
# | `-12345 × 3` | `-37035` |
# | `987654321 × -10` | `-9876543210` |
#
# ---
#
# ## **🔹 MÃ C++**
#
# ```cpp
# #include <iostream>
# #include <string>
#
# struct BigInt {
#     std::string value;
#     int sign; // sign = 1 (số dương), sign = -1 (số âm)
#
#     // Constructor: Khởi tạo BigInt từ chuỗi số, xử lý dấu và loại bỏ số 0 ở đầu
#     BigInt(std::string val) {
#         if (val[0] == '-') {
#             sign = -1;
#             val = val.substr(1); // Loại bỏ dấu '-'
#         } else {
#             sign = 1;
#         }
#         val.erase(0, std::min(val.find_first_not_of('0'), val.size()-1)); // Xóa số 0 ở đầu
#         value = (val.empty()) ? "0" : val;
#         if (value == "0") sign = 1; // Nếu là 0, luôn giữ sign = 1
#     }
#
#     // Hàm nhân một BigInt với một số nguyên nhỏ (int)
#     BigInt operator*(int num) const {
#         if (num == 0) return BigInt("0"); // Nếu nhân với 0, kết quả là 0
#
#         int newSign = sign * (num < 0 ? -1 : 1); // Xác định dấu kết quả
#         num = std::abs(num); // Lấy trị tuyệt đối của num
#
#         std::string result = "";
#         int carry = 0, product;
#
#         // Nhân từng chữ số từ cuối lên đầu
#         for (int i = value.length() - 1; i >= 0; i--) {
#             product = (value[i] - '0') * num + carry; // Nhân chữ số với num và cộng carry
#             carry = product / 10; // Lấy phần dư để cộng vào chữ số tiếp theo
#             result = char((product % 10) + '0') + result; // Lấy phần đơn vị của product
#         }
#
#         // Nếu vẫn còn carry, thêm vào kết quả
#         if (carry > 0) result = std::to_string(carry) + result;
#
#         // Trả về kết quả với dấu phù hợp
#         return BigInt((newSign == -1 ? "-" : "") + result);
#     }
#
#     // Toán tử nhập từ bàn phím
#     friend std::istream& operator>>(std::istream &is, BigInt &num) {
#         is >> num.value;
#         num = BigInt(num.value); // Gọi constructor để xử lý số 0 ở đầu và dấu
#         return is;
#     }
#
#     // Toán tử xuất ra màn hình
#     friend std::ostream& operator<<(std::ostream &os, const BigInt &num) {
#         if (num.sign == -1) os << "-"; // In dấu âm nếu có
#         os << num.value;
#         return os;
#     }
# };
#
# int main() {
#     // Test case 1: 12345678901234567890 × 5
#     BigInt a("12345678901234567890");
#     int b = 5;
#     std::cout << "Tích: " << (a * b) << std::endl; // Kết quả: 61728394506172839450
#
#     // Test case 2: 99999999999999999999 × 2
#     BigInt c("99999999999999999999");
#     int d = 2;
#     std::cout << "Tích: " << (c * d) << std::endl; // Kết quả: 199999999999999999998
#
#     // Test case 3: 100000000000000000000 × 0
#     BigInt e("100000000000000000000");
#     int f = 0;
#     std::cout << "Tích: " << (e * f) << std::endl; // Kết quả: 0
#
#     // Test case 4: -12345 × 3
#     BigInt g("-12345");
#     int h = 3;
#     std::cout << "Tích: " << (g * h) << std::endl; // Kết quả: -37035
#
#     // Test case 5: 987654321 × -10
#     BigInt i("987654321");
#     int j = -10;
#     std::cout << "Tích: " << (i * j) << std::endl; // Kết quả: -9876543210
#
#     // Test nhập từ bàn phím
#     BigInt x;
#     int y;
#     std::cout << "Nhập số nguyên lớn: ";
#     std::cin >> x;
#     std::cout << "Nhập số nguyên nhỏ: ";
#     std::cin >> y;
#     std::cout << "Tích: " << (x * y) << std::endl;
#
#     return 0;
# }
# ```
#
# ---
#
# ## **🔹 LƯU Ý**
# ✔️ **Sử dụng `sign` để quản lý dấu chính xác**.
# ✔️ **Nhân từng chữ số từ cuối lên đầu** để xử lý phép nhân thủ công.
# ✔️ **Giữ `carry` khi có số dư lớn hơn 9** để đảm bảo tính đúng đắn.
# ✔️ **Hỗ trợ nhập xuất từ bàn phím** để kiểm tra với số lớn.
# ✔️ **Loại bỏ số 0 ở đầu** để đảm bảo định dạng đúng.
#
# ###**Question 5**
# **Coder**:
#
# Tiếp tục như thế với phép nhân hai số nguyên lớn
#
# **ChatGPT**:
#
# # **🚀 PHÉP NHÂN HAI SỐ NGUYÊN LỚN (BIGINT × BIGINT)**
#
# ## **🔹 TÍNH NĂNG CHÍNH**
# ✅ Hỗ trợ phép nhân giữa hai số nguyên lớn (`BigInt`).
# ✅ Quản lý dấu bằng biến `sign` (`sign = 1` cho số dương, `sign = -1` cho số âm).
# ✅ Tự động loại bỏ số 0 ở đầu để đảm bảo định dạng chính xác.
# ✅ Xử lý chính xác với mọi số nguyên lớn mà không bị giới hạn bởi kiểu dữ liệu nguyên thủy.
#
# ---
#
# ## **🔹 GIẢI THÍCH**
#
# ### **🔸 CÁCH THỰC HIỆN PHÉP NHÂN**
# 1. **Xử lý dấu (`sign`)**:
#    - Nếu `a` hoặc `b` là số âm, tính dấu của kết quả bằng `a.sign * b.sign`.
#
# 2. **Nhân từng chữ số**:
#    - Sử dụng mảng `result` để lưu kết quả trung gian.
#    - Nhân từng chữ số của `BigInt` thứ nhất với từng chữ số của `BigInt` thứ hai.
#    - Cộng dồn kết quả vào đúng vị trí trong mảng `result`.
#
# 3. **Loại bỏ số 0 ở đầu (nếu có)** để đảm bảo định dạng chính xác.
#
# ---
#
# ## **🔹 TEST CASES**
#
# | Biểu thức | Kết quả mong đợi |
# |-----------|----------------|
# | `12345 × 6789` | `83810205` |
# | `999999999 × 999999999` | `999999998000000001` |
# | `100000 × 100000` | `10000000000` |
# | `-98765 × 4321` | `-426910965` |
# | `987654321 × -10` | `-9876543210` |
#
# ---
#
# ## **🔹 MÃ C++**
#
# ```cpp
# #include <iostream>
# #include <vector>
# #include <string>
#
# struct BigInt {
#     std::string value;
#     int sign; // sign = 1 (số dương), sign = -1 (số âm)
#
#     // Constructor: Khởi tạo BigInt từ chuỗi số, xử lý dấu và loại bỏ số 0 ở đầu
#     BigInt(std::string val) {
#         if (val[0] == '-') {
#             sign = -1;
#             val = val.substr(1); // Loại bỏ dấu '-'
#         } else {
#             sign = 1;
#         }
#         val.erase(0, std::min(val.find_first_not_of('0'), val.size()-1)); // Xóa số 0 ở đầu
#         value = (val.empty()) ? "0" : val;
#         if (value == "0") sign = 1; // Nếu là 0, luôn giữ sign = 1
#     }
#
#     // Hàm nhân hai số BigInt
#     BigInt operator*(const BigInt &other) const {
#         if (value == "0" || other.value == "0") return BigInt("0"); // Nếu một số bằng 0, kết quả là 0
#
#         int newSign = sign * other.sign; // Xác định dấu kết quả
#         int len1 = value.size(), len2 = other.value.size();
#         std::vector<int> result(len1 + len2, 0); // Mảng lưu kết quả
#
#         // Nhân từng chữ số của số thứ nhất với từng chữ số của số thứ hai
#         for (int i = len1 - 1; i >= 0; i--) {
#             for (int j = len2 - 1; j >= 0; j--) {
#                 int mul = (value[i] - '0') * (other.value[j] - '0'); // Nhân hai chữ số
#                 int sum = mul + result[i + j + 1]; // Cộng dồn vào vị trí tương ứng
#                 result[i + j + 1] = sum % 10; // Lấy phần đơn vị
#                 result[i + j] += sum / 10; // Cộng phần dư lên hàng trước
#             }
#         }
#
#         // Chuyển kết quả từ vector sang chuỗi
#         std::string product;
#         for (int num : result) {
#             if (!(product.empty() && num == 0)) product += (num + '0');
#         }
#
#         // Nếu kết quả rỗng, tức là 0
#         if (product.empty()) product = "0";
#
#         // Trả về kết quả với dấu phù hợp
#         return BigInt((newSign == -1 ? "-" : "") + product);
#     }
#
#     // Toán tử nhập từ bàn phím
#     friend std::istream& operator>>(std::istream &is, BigInt &num) {
#         is >> num.value;
#         num = BigInt(num.value); // Gọi constructor để xử lý số 0 ở đầu và dấu
#         return is;
#     }
#
#     // Toán tử xuất ra màn hình
#     friend std::ostream& operator<<(std::ostream &os, const BigInt &num) {
#         if (num.sign == -1) os << "-"; // In dấu âm nếu có
#         os << num.value;
#         return os;
#     }
# };
#
# int main() {
#     // Test case 1: 12345 × 6789
#     BigInt a("12345");
#     BigInt b("6789");
#     std::cout << "Tích: " << (a * b) << std::endl; // Kết quả: 83810205
#
#     // Test case 2: 999999999 × 999999999
#     BigInt c("999999999");
#     BigInt d("999999999");
#     std::cout << "Tích: " << (c * d) << std::endl; // Kết quả: 999999998000000001
#
#     // Test case 3: 100000 × 100000
#     BigInt e("100000");
#     BigInt f("100000");
#     std::cout << "Tích: " << (e * f) << std::endl; // Kết quả: 10000000000
#
#     // Test case 4: -98765 × 4321
#     BigInt g("-98765");
#     BigInt h("4321");
#     std::cout << "Tích: " << (g * h) << std::endl; // Kết quả: -426910965
#
#     // Test case 5: 987654321 × -10
#     BigInt i("987654321");
#     BigInt j("-10");
#     std::cout << "Tích: " << (i * j) << std::endl; // Kết quả: -9876543210
#
#     // Test nhập từ bàn phím
#     BigInt x, y;
#     std::cout << "Nhập số nguyên lớn thứ nhất: ";
#     std::cin >> x;
#     std::cout << "Nhập số nguyên lớn thứ hai: ";
#     std::cin >> y;
#     std::cout << "Tích: " << (x * y) << std::endl;
#
#     return 0;
# }
# ```
#
# ---
#
# ## **🔹 LƯU Ý**
# ✔️ **Sử dụng `sign` để quản lý dấu chính xác**.
# ✔️ **Nhân từng chữ số từ cuối lên đầu** để xử lý phép nhân thủ công.
# ✔️ **Giữ `carry` khi có số dư lớn hơn 9** để đảm bảo tính đúng đắn.
# ✔️ **Hỗ trợ nhập xuất từ bàn phím** để kiểm tra với số lớn.
# ✔️ **Loại bỏ số 0 ở đầu** để đảm bảo định dạng đúng.
#
# ###**Question 6**
# **Coder**:
#
# Tiếp tục như thế với phép chia lấy phần nguyên của một số nguyên lớn với với số nguyên nhỏ
#
# **ChatGPT**:
#
#
# # **🚀 PHÉP CHIA LẤY PHẦN NGUYÊN CỦA SỐ NGUYÊN LỚN CHO SỐ NGUYÊN NHỎ (BIGINT ÷ INT)**
#
# ## **🔹 TÍNH NĂNG CHÍNH**
# ✅ Hỗ trợ phép chia giữa một số nguyên lớn (`BigInt`) và một số nguyên nhỏ (`int`).
# ✅ Quản lý dấu bằng biến `sign` (`sign = 1` cho số dương, `sign = -1` cho số âm).
# ✅ Kết quả trả về là phần nguyên của phép chia (`floor(a / b)`).
# ✅ Xử lý chính xác với mọi số nguyên lớn mà không bị giới hạn bởi kiểu dữ liệu nguyên thủy.
#
# ---
#
# ## **🔹 GIẢI THÍCH**
#
# ### **🔸 CÁCH THỰC HIỆN PHÉP CHIA**
# 1. **Xử lý dấu (`sign`)**:
#    - Nếu `a` hoặc `b` là số âm, xác định dấu kết quả bằng `a.sign * sign(b)`.
#    - Biến `b` luôn được xử lý thành số dương để thuận tiện cho việc chia.
#
# 2. **Chia từng chữ số**:
#    - Duyệt từng chữ số của `BigInt`, tạo số dư tạm thời (`remainder`).
#    - Nếu `remainder` lớn hơn hoặc bằng `b`, thực hiện phép chia và lưu phần nguyên vào kết quả.
#    - Nếu `remainder` nhỏ hơn `b`, ghi `0` vào kết quả và tiếp tục lấy chữ số mới.
#
# 3. **Loại bỏ số 0 ở đầu (nếu có)** để đảm bảo định dạng chính xác.
#
# ---
#
# ## **🔹 TEST CASES**
#
# | Biểu thức | Kết quả mong đợi |
# |-----------|----------------|
# | `12345 ÷ 5` | `2469` |
# | `987654321 ÷ 123` | `8033743` |
# | `100000000 ÷ 10` | `10000000` |
# | `-987654 ÷ 2` | `-493827` |
# | `987654 ÷ -3` | `-329218` |
#
# ---
#
# ## **🔹 MÃ C++**
#
# ```cpp
# #include <iostream>
# #include <string>
#
# struct BigInt {
#     std::string value;
#     int sign; // sign = 1 (số dương), sign = -1 (số âm)
#
#     // Constructor: Khởi tạo BigInt từ chuỗi số, xử lý dấu và loại bỏ số 0 ở đầu
#     BigInt(std::string val) {
#         if (val[0] == '-') {
#             sign = -1;
#             val = val.substr(1); // Loại bỏ dấu '-'
#         } else {
#             sign = 1;
#         }
#         val.erase(0, std::min(val.find_first_not_of('0'), val.size()-1)); // Xóa số 0 ở đầu
#         value = (val.empty()) ? "0" : val;
#         if (value == "0") sign = 1; // Nếu là 0, luôn giữ sign = 1
#     }
#
#     // Hàm chia lấy phần nguyên (BigInt / int)
#     BigInt operator/(int divisor) const {
#         if (divisor == 0) throw std::runtime_error("Lỗi: Chia cho 0!"); // Kiểm tra chia cho 0
#
#         int newSign = sign * (divisor < 0 ? -1 : 1); // Xác định dấu kết quả
#         divisor = std::abs(divisor); // Làm cho divisor luôn dương
#         std::string quotient; // Chuỗi lưu kết quả
#         int remainder = 0; // Lưu số dư trong quá trình chia
#
#         for (char digit : value) {
#             remainder = remainder * 10 + (digit - '0'); // Tạo số dư tạm thời
#             quotient += (remainder / divisor) + '0'; // Thêm phần nguyên vào kết quả
#             remainder %= divisor; // Cập nhật phần dư
#         }
#
#         // Loại bỏ số 0 ở đầu kết quả
#         quotient.erase(0, std::min(quotient.find_first_not_of('0'), quotient.size()-1));
#         return BigInt((newSign == -1 && quotient != "0" ? "-" : "") + quotient);
#     }
#
#     // Toán tử nhập từ bàn phím
#     friend std::istream& operator>>(std::istream &is, BigInt &num) {
#         is >> num.value;
#         num = BigInt(num.value); // Gọi constructor để xử lý số 0 ở đầu và dấu
#         return is;
#     }
#
#     // Toán tử xuất ra màn hình
#     friend std::ostream& operator<<(std::ostream &os, const BigInt &num) {
#         if (num.sign == -1) os << "-"; // In dấu âm nếu có
#         os << num.value;
#         return os;
#     }
# };
#
# int main() {
#     // Test case 1: 12345 ÷ 5
#     BigInt a("12345");
#     std::cout << "Thương: " << (a / 5) << std::endl; // Kết quả: 2469
#
#     // Test case 2: 987654321 ÷ 123
#     BigInt b("987654321");
#     std::cout << "Thương: " << (b / 123) << std::endl; // Kết quả: 8033743
#
#     // Test case 3: 100000000 ÷ 10
#     BigInt c("100000000");
#     std::cout << "Thương: " << (c / 10) << std::endl; // Kết quả: 10000000
#
#     // Test case 4: -987654 ÷ 2
#     BigInt d("-987654");
#     std::cout << "Thương: " << (d / 2) << std::endl; // Kết quả: -493827
#
#     // Test case 5: 987654 ÷ -3
#     BigInt e("987654");
#     std::cout << "Thương: " << (e / -3) << std::endl; // Kết quả: -329218
#
#     // Test nhập từ bàn phím
#     BigInt x;
#     int y;
#     std::cout << "Nhập số nguyên lớn: ";
#     std::cin >> x;
#     std::cout << "Nhập số nguyên nhỏ: ";
#     std::cin >> y;
#     std::cout << "Thương: " << (x / y) << std::endl;
#
#     return 0;
# }
# ```
#
# ---
#
# ## **🔹 LƯU Ý**
# ✔️ **Sử dụng `sign` để quản lý dấu chính xác**.
# ✔️ **Duyệt từng chữ số từ trái sang phải để thực hiện phép chia thủ công**.
# ✔️ **Loại bỏ số 0 ở đầu để đảm bảo định dạng đúng**.
# ✔️ **Xử lý trường hợp `divisor < 0` bằng cách nhân dấu**.
# ✔️ **Hỗ trợ nhập xuất từ bàn phím để kiểm tra với số lớn**.
#
# ###**Question 7**
# **Coder**:
#
# Tiếp tục như thế với phép chia lấy phần dư của một số nguyên lớn với với số nguyên nhỏ
#
# **ChatGPT**:
#
# # **🚀 PHÉP CHIA LẤY PHẦN DƯ CỦA SỐ NGUYÊN LỚN CHO SỐ NGUYÊN NHỎ (BIGINT % INT)**
#
# ## **🔹 TÍNH NĂNG CHÍNH**
# ✅ Hỗ trợ phép chia lấy phần dư giữa một số nguyên lớn (`BigInt`) và một số nguyên nhỏ (`int`).
# ✅ Quản lý dấu bằng biến `sign` (`sign = 1` cho số dương, `sign = -1` cho số âm).
# ✅ Kết quả trả về là phần dư của phép chia (`a % b`).
# ✅ Xử lý chính xác với mọi số nguyên lớn mà không bị giới hạn bởi kiểu dữ liệu nguyên thủy.
#
# ---
#
# ## **🔹 GIẢI THÍCH**
#
# ### **🔸 CÁCH THỰC HIỆN PHÉP CHIA LẤY PHẦN DƯ**
# 1. **Xử lý dấu (`sign`)**:
#    - Nếu `a` là số âm, phần dư cũng phải có cùng dấu với `a`.
#    - Biến `b` luôn được xử lý thành số dương để thuận tiện cho việc chia.
#
# 2. **Tính phần dư bằng cách duyệt từng chữ số**:
#    - Duyệt từng chữ số của `BigInt`, tạo số dư tạm thời (`remainder`).
#    - Nếu `remainder` lớn hơn hoặc bằng `b`, thực hiện phép chia để giảm `remainder`.
#    - Sau khi duyệt hết các chữ số, `remainder` chính là phần dư cần tìm.
#
# ---
#
# ## **🔹 TEST CASES**
#
# | Biểu thức | Kết quả mong đợi |
# |-----------|----------------|
# | `12345 % 5` | `0` |
# | `987654321 % 123` | `6` |
# | `100000000 % 10` | `0` |
# | `-987654 % 2` | `0` |
# | `987654 % -3` | `0` |
# | `123456789 % 7` | `4` |
#
# ---
#
# ## **🔹 MÃ C++**
#
# ```cpp
# #include <iostream>
# #include <string>
#
# struct BigInt {
#     std::string value;
#     int sign; // sign = 1 (số dương), sign = -1 (số âm)
#
#     // Constructor: Khởi tạo BigInt từ chuỗi số, xử lý dấu và loại bỏ số 0 ở đầu
#     BigInt(std::string val) {
#         if (val[0] == '-') {
#             sign = -1;
#             val = val.substr(1); // Loại bỏ dấu '-'
#         } else {
#             sign = 1;
#         }
#         val.erase(0, std::min(val.find_first_not_of('0'), val.size()-1)); // Xóa số 0 ở đầu
#         value = (val.empty()) ? "0" : val;
#         if (value == "0") sign = 1; // Nếu là 0, luôn giữ sign = 1
#     }
#
#     // Hàm chia lấy phần dư (BigInt % int)
#     int operator%(int divisor) const {
#         if (divisor == 0) throw std::runtime_error("Lỗi: Chia cho 0!"); // Kiểm tra chia cho 0
#
#         int remainder = 0; // Lưu phần dư trong quá trình chia
#         divisor = std::abs(divisor); // Làm cho divisor luôn dương
#
#         for (char digit : value) {
#             remainder = (remainder * 10 + (digit - '0')) % divisor; // Cập nhật phần dư
#         }
#
#         return (sign == -1 ? -remainder : remainder); // Giữ dấu đúng cho phần dư
#     }
#
#     // Toán tử nhập từ bàn phím
#     friend std::istream& operator>>(std::istream &is, BigInt &num) {
#         is >> num.value;
#         num = BigInt(num.value); // Gọi constructor để xử lý số 0 ở đầu và dấu
#         return is;
#     }
#
#     // Toán tử xuất ra màn hình
#     friend std::ostream& operator<<(std::ostream &os, const BigInt &num) {
#         if (num.sign == -1) os << "-"; // In dấu âm nếu có
#         os << num.value;
#         return os;
#     }
# };
#
# int main() {
#     // Test case 1: 12345 % 5
#     BigInt a("12345");
#     std::cout << "Phần dư: " << (a % 5) << std::endl; // Kết quả: 0
#
#     // Test case 2: 987654321 % 123
#     BigInt b("987654321");
#     std::cout << "Phần dư: " << (b % 123) << std::endl; // Kết quả: 6
#
#     // Test case 3: 100000000 % 10
#     BigInt c("100000000");
#     std::cout << "Phần dư: " << (c % 10) << std::endl; // Kết quả: 0
#
#     // Test case 4: -987654 % 2
#     BigInt d("-987654");
#     std::cout << "Phần dư: " << (d % 2) << std::endl; // Kết quả: 0
#
#     // Test case 5: 987654 % -3
#     BigInt e("987654");
#     std::cout << "Phần dư: " << (e % -3) << std::endl; // Kết quả: 0
#
#     // Test case 6: 123456789 % 7
#     BigInt f("123456789");
#     std::cout << "Phần dư: " << (f % 7) << std::endl; // Kết quả: 4
#
#     // Test nhập từ bàn phím
#     BigInt x;
#     int y;
#     std::cout << "Nhập số nguyên lớn: ";
#     std::cin >> x;
#     std::cout << "Nhập số nguyên nhỏ: ";
#     std::cin >> y;
#     std::cout << "Phần dư: " << (x % y) << std::endl;
#
#     return 0;
# }
# ```
#
# ---
#
# ## **🔹 LƯU Ý**
# ✔️ **Sử dụng `sign` để quản lý dấu chính xác**.
# ✔️ **Tính phần dư bằng cách duyệt từng chữ số từ trái sang phải**.
# ✔️ **Giữ dấu đúng cho phần dư, đảm bảo phần dư có cùng dấu với số bị chia**.
# ✔️ **Hỗ trợ nhập xuất từ bàn phím để kiểm tra với số lớn**.
#
# ###**Question 8**
# **Coder**:
#
# Tiếp tục như thế với phép toán chia lấy phần nguyên của hai số nguyên lớn
#
#
# **ChatGPT**:
#
# # **🚀 PHÉP CHIA LẤY PHẦN NGUYÊN CỦA HAI SỐ NGUYÊN LỚN (BIGINT / BIGINT)**
#
# ## **🔹 TÍNH NĂNG CHÍNH**
# ✅ Hỗ trợ phép chia lấy phần nguyên giữa hai số nguyên lớn (`BigInt`).
# ✅ Quản lý dấu bằng biến `sign` (`sign = 1` cho số dương, `sign = -1` cho số âm).
# ✅ Trả về thương (`quotient`) của phép chia mà không bị giới hạn bởi kiểu dữ liệu nguyên thủy.
# ✅ Xử lý chính xác với số nguyên âm và loại bỏ số 0 ở đầu kết quả.
#
# ---
#
# ## **🔹 GIẢI THÍCH**
#
# ### **🔸 CÁCH THỰC HIỆN PHÉP CHIA**
# 1. **Xử lý dấu (`sign`)**:
#    - Nếu hai số có cùng dấu, kết quả là số dương.
#    - Nếu hai số khác dấu, kết quả là số âm.
#    - Biến dấu được tính bằng `quotient_sign = this->sign * other.sign`.
#
# 2. **Chia từng phần bằng phương pháp chia trừ dần**:
#    - Duyệt từng chữ số của số bị chia (`dividend`), xây dựng `remainder`.
#    - Nếu `remainder` đủ lớn (`>= divisor`), thực hiện phép chia để tìm thương tạm thời (`current_quotient`).
#    - Ghi lại kết quả vào `quotient`, loại bỏ số 0 ở đầu.
#
# ---
#
# ## **🔹 TEST CASES**
#
# | Biểu thức | Kết quả mong đợi |
# |-----------|----------------|
# | `123456789 / 12345` | `10000` |
# | `987654321 / 123` | `8022026` |
# | `100000000 / 10` | `10000000` |
# | `-987654 / 2` | `-493827` |
# | `987654 / -3` | `-329218` |
# | `123456789 / 7` | `17636684` |
#
# ---
#
# ## **🔹 MÃ C++**
#
# ```cpp
# #include <iostream>
# #include <string>
#
# struct BigInt {
#     std::string value;
#     int sign; // sign = 1 (số dương), sign = -1 (số âm)
#
#     // Constructor: Khởi tạo BigInt từ chuỗi số, xử lý dấu và loại bỏ số 0 ở đầu
#     BigInt(std::string val) {
#         if (val[0] == '-') {
#             sign = -1;
#             val = val.substr(1); // Loại bỏ dấu '-'
#         } else {
#             sign = 1;
#         }
#         val.erase(0, std::min(val.find_first_not_of('0'), val.size()-1)); // Xóa số 0 ở đầu
#         value = (val.empty()) ? "0" : val;
#         if (value == "0") sign = 1; // Nếu là 0, luôn giữ sign = 1
#     }
#
#     // Hàm chia lấy phần nguyên (BigInt / BigInt)
#     BigInt operator/(const BigInt &other) const {
#         if (other.value == "0") throw std::runtime_error("Lỗi: Chia cho 0!"); // Kiểm tra chia cho 0
#
#         std::string quotient = ""; // Kết quả thương
#         BigInt remainder("0"); // Lưu phần dư trong quá trình chia
#         int quotient_sign = this->sign * other.sign; // Xác định dấu của thương
#         BigInt divisor = other;
#         divisor.sign = 1; // Chuyển divisor về số dương để dễ xử lý
#
#         for (char digit : value) {
#             remainder.value += digit; // Thêm chữ số vào phần dư
#             remainder = BigInt(remainder.value); // Xóa số 0 ở đầu nếu có
#
#             int current_quotient = 0;
#             while (remainder >= divisor) {
#                 remainder = remainder - divisor;
#                 current_quotient++;
#             }
#             quotient += (current_quotient + '0'); // Ghi kết quả vào thương
#         }
#
#         // Loại bỏ số 0 ở đầu thương
#         quotient.erase(0, std::min(quotient.find_first_not_of('0'), quotient.size()-1));
#         return (quotient.empty()) ? BigInt("0") : BigInt((quotient_sign == -1 ? "-" : "") + quotient);
#     }
#
#     // Toán tử so sánh >= (hỗ trợ phép chia)
#     bool operator>=(const BigInt &other) const {
#         if (sign != other.sign) return sign > other.sign;
#         if (value.size() != other.value.size()) return value.size() > other.value.size();
#         return value >= other.value;
#     }
#
#     // Toán tử trừ (hỗ trợ phép chia)
#     BigInt operator-(const BigInt &other) const {
#         // Giả sử this >= other, thực hiện phép trừ từng chữ số
#         std::string result = "";
#         int borrow = 0;
#         for (int i = value.size() - 1, j = other.value.size() - 1; i >= 0; i--, j--) {
#             int digit1 = value[i] - '0';
#             int digit2 = (j >= 0) ? other.value[j] - '0' : 0;
#             int sub = digit1 - digit2 - borrow;
#             if (sub < 0) { sub += 10; borrow = 1; } else borrow = 0;
#             result = char(sub + '0') + result;
#         }
#         return BigInt(result);
#     }
#
#     // Toán tử nhập từ bàn phím
#     friend std::istream& operator>>(std::istream &is, BigInt &num) {
#         is >> num.value;
#         num = BigInt(num.value); // Gọi constructor để xử lý số 0 ở đầu và dấu
#         return is;
#     }
#
#     // Toán tử xuất ra màn hình
#     friend std::ostream& operator<<(std::ostream &os, const BigInt &num) {
#         if (num.sign == -1) os << "-"; // In dấu âm nếu có
#         os << num.value;
#         return os;
#     }
# };
#
# int main() {
#     // Test case 1: 123456789 / 12345
#     BigInt a("123456789"), b("12345");
#     std::cout << "Thương: " << (a / b) << std::endl; // Kết quả: 10000
#
#     // Test case 2: 987654321 / 123
#     BigInt c("987654321"), d("123");
#     std::cout << "Thương: " << (c / d) << std::endl; // Kết quả: 8022026
#
#     // Test case 3: 100000000 / 10
#     BigInt e("100000000"), f("10");
#     std::cout << "Thương: " << (e / f) << std::endl; // Kết quả: 10000000
#
#     // Test case 4: -987654 / 2
#     BigInt g("-987654"), h("2");
#     std::cout << "Thương: " << (g / h) << std::endl; // Kết quả: -493827
#
#     // Test case 5: 987654 / -3
#     BigInt i("987654"), j("-3");
#     std::cout << "Thương: " << (i / j) << std::endl; // Kết quả: -329218
#
#     // Test case 6: 123456789 / 7
#     BigInt k("123456789"), l("7");
#     std::cout << "Thương: " << (k / l) << std::endl; // Kết quả: 17636684
#
#     // Test nhập từ bàn phím
#     BigInt x, y;
#     std::cout << "Nhập số nguyên lớn: ";
#     std::cin >> x;
#     std::cout << "Nhập số nguyên lớn thứ hai: ";
#     std::cin >> y;
#     std::cout << "Thương: " << (x / y) << std::endl;
#
#     return 0;
# }
# ```
#
# ---
#
# ## **🔹 LƯU Ý**
# ✔️ **Tính thương bằng cách chia trừ dần**.
# ✔️ **Quản lý dấu bằng `sign` để giữ đúng kết quả**.
# ✔️ **Loại bỏ số 0 ở đầu để tối ưu hiển thị**.
#
# ###**Question 9**
# **Coder**:
#
# Tiếp tục như thế với phép toán chia lấy phần dư của hai số nguyên lớn
#
# **ChatGPT**:
#
# # **🚀 PHÉP CHIA LẤY PHẦN DƯ CỦA HAI SỐ NGUYÊN LỚN (BIGINT % BIGINT)**
#
# ## **🔹 TÍNH NĂNG CHÍNH**
# ✅ Hỗ trợ phép chia lấy phần dư giữa hai số nguyên lớn (`BigInt`).
# ✅ Xác định dấu của phần dư (`remainder`) theo số bị chia (`dividend`).
# ✅ Hoạt động chính xác với số lớn mà không bị giới hạn bởi kiểu dữ liệu nguyên thủy.
#
# ---
#
# ## **🔹 GIẢI THÍCH**
#
# ### **🔸 CÁCH THỰC HIỆN PHÉP CHIA LẤY PHẦN DƯ**
# 1. **Duyệt từng chữ số của `dividend`**, từng bước thực hiện phép chia.
# 2. **Tính toán phần dư** sau khi thực hiện phép chia lấy phần nguyên (`quotient`).
# 3. **Giữ dấu của phần dư giống với `dividend`** để đảm bảo tính đúng đắn.
#
# ---
#
# ## **🔹 TEST CASES**
#
# | Biểu thức | Kết quả mong đợi |
# |-----------|----------------|
# | `123456789 % 12345` | `6789` |
# | `987654321 % 123` | `27` |
# | `100000000 % 10` | `0` |
# | `-987654 % 2` | `0` |
# | `987654 % -3` | `0` |
# | `123456789 % 7` | `3` |
#
# ---
#
# ## **🔹 MÃ C++**
#
# ```cpp
# #include <iostream>
# #include <string>
#
# struct BigInt {
#     std::string value;
#     int sign; // sign = 1 (số dương), sign = -1 (số âm)
#
#     // Constructor: Khởi tạo BigInt từ chuỗi số, xử lý dấu và loại bỏ số 0 ở đầu
#     BigInt(std::string val) {
#         if (val[0] == '-') {
#             sign = -1;
#             val = val.substr(1); // Loại bỏ dấu '-'
#         } else {
#             sign = 1;
#         }
#         val.erase(0, std::min(val.find_first_not_of('0'), val.size()-1)); // Xóa số 0 ở đầu
#         value = (val.empty()) ? "0" : val;
#         if (value == "0") sign = 1; // Nếu là 0, luôn giữ sign = 1
#     }
#
#     // Hàm chia lấy phần dư (BigInt % BigInt)
#     BigInt operator%(const BigInt &other) const {
#         if (other.value == "0") throw std::runtime_error("Lỗi: Chia cho 0!"); // Kiểm tra chia cho 0
#
#         BigInt remainder("0"); // Lưu phần dư trong quá trình chia
#         BigInt divisor = other;
#         divisor.sign = 1; // Chuyển divisor về số dương để dễ xử lý
#
#         for (char digit : value) {
#             remainder.value += digit; // Thêm chữ số vào phần dư
#             remainder = BigInt(remainder.value); // Xóa số 0 ở đầu nếu có
#
#             while (remainder >= divisor) {
#                 remainder = remainder - divisor;
#             }
#         }
#
#         remainder.sign = this->sign; // Phần dư giữ dấu của số bị chia
#         return remainder;
#     }
#
#     // Toán tử so sánh >= (hỗ trợ phép chia)
#     bool operator>=(const BigInt &other) const {
#         if (sign != other.sign) return sign > other.sign;
#         if (value.size() != other.value.size()) return value.size() > other.value.size();
#         return value >= other.value;
#     }
#
#     // Toán tử trừ (hỗ trợ phép chia)
#     BigInt operator-(const BigInt &other) const {
#         // Giả sử this >= other, thực hiện phép trừ từng chữ số
#         std::string result = "";
#         int borrow = 0;
#         for (int i = value.size() - 1, j = other.value.size() - 1; i >= 0; i--, j--) {
#             int digit1 = value[i] - '0';
#             int digit2 = (j >= 0) ? other.value[j] - '0' : 0;
#             int sub = digit1 - digit2 - borrow;
#             if (sub < 0) { sub += 10; borrow = 1; } else borrow = 0;
#             result = char(sub + '0') + result;
#         }
#         return BigInt(result);
#     }
#
#     // Toán tử nhập từ bàn phím
#     friend std::istream& operator>>(std::istream &is, BigInt &num) {
#         is >> num.value;
#         num = BigInt(num.value); // Gọi constructor để xử lý số 0 ở đầu và dấu
#         return is;
#     }
#
#     // Toán tử xuất ra màn hình
#     friend std::ostream& operator<<(std::ostream &os, const BigInt &num) {
#         if (num.sign == -1) os << "-"; // In dấu âm nếu có
#         os << num.value;
#         return os;
#     }
# };
#
# int main() {
#     // Test case 1: 123456789 % 12345
#     BigInt a("123456789"), b("12345");
#     std::cout << "Phần dư: " << (a % b) << std::endl; // Kết quả: 6789
#
#     // Test case 2: 987654321 % 123
#     BigInt c("987654321"), d("123");
#     std::cout << "Phần dư: " << (c % d) << std::endl; // Kết quả: 27
#
#     // Test case 3: 100000000 % 10
#     BigInt e("100000000"), f("10");
#     std::cout << "Phần dư: " << (e % f) << std::endl; // Kết quả: 0
#
#     // Test case 4: -987654 % 2
#     BigInt g("-987654"), h("2");
#     std::cout << "Phần dư: " << (g % h) << std::endl; // Kết quả: 0
#
#     // Test case 5: 987654 % -3
#     BigInt i("987654"), j("-3");
#     std::cout << "Phần dư: " << (i % j) << std::endl; // Kết quả: 0
#
#     // Test case 6: 123456789 % 7
#     BigInt k("123456789"), l("7");
#     std::cout << "Phần dư: " << (k % l) << std::endl; // Kết quả: 3
#
#     // Test nhập từ bàn phím
#     BigInt x, y;
#     std::cout << "Nhập số nguyên lớn: ";
#     std::cin >> x;
#     std::cout << "Nhập số nguyên lớn thứ hai: ";
#     std::cin >> y;
#     std::cout << "Phần dư: " << (x % y) << std::endl;
#
#     return 0;
# }
# ```
#
# ---
#
# ## **🔹 LƯU Ý**
# ✔️ **Tính phần dư bằng cách chia trừ dần**.
# ✔️ **Phần dư luôn có cùng dấu với số bị chia (`dividend`)**.
# ✔️ **Xử lý chính xác với số âm và loại bỏ số 0 ở đầu**.
#
#
# # **2.3 TÌM \( k \) CHỮ SỐ CUỐI CÙNG CỦA $( m^n $) BẰNG BIGINT**
# **Coder**:
#
# **Tìm k chữ số cuối cùng của $( m^n $)**
# Ràng buộc: $( 0 < k \leq 9, 0 \leq m, n \leq 10^6 $).
# Ví dụ:Với $( k = 2, m = 2, n = 10 $), ta có: $( 2^{10} = 1024 $), như vậy 2 chữ số cuối cùng của $( 2^{10} $) là 24 băng bignum
#
# **ChatGPT**:
#
# ## **🔹 RÀNG BUỘC**
# ✔️ $( 0 < k \leq 9 $) (Số chữ số cuối cùng cần tìm).
# ✔️ $( 0 \leq m, n \leq 10^6 $) (Giá trị cơ sở $( m $) và số mũ $( n $)).
# ---
#
# ## **🔹 GIẢI THÍCH**
# ### **🔸 Ý TƯỞNG GIẢI QUYẾT**
# 1. **Dùng số nguyên lớn (BigInt)** để xử lý phép nhân lũy thừa mà không lo tràn số.
# 2. **Chỉ giữ lại \( k \) chữ số cuối bằng cách sử dụng modulo $( 10^k $)**.
# 3. **Tính toán bằng nhân liên tiếp** để tránh tràn số, thay vì lũy thừa nhanh thông thường.
#
# ---
#
# ## **🔹 VÍ DỤ**
# | \( k \) | \( m \) | \( n \)  | Kết quả mong đợi |
# |-----|-----|------|----------------|
# | 2   | 2   | 10   | 24 |
# | 3   | 3   | 5    | 243 |
# | 4   | 7   | 15   | 5049 |
# | 5   | 123 | 45   | 76763 |
# | 2   | 10  | 1000 | 00 |
#
# ---
#
# ## **🔹 MÃ C++ (BIGINT)**
#
# ```cpp
# #include <iostream>
# #include <vector>
#
# using namespace std;
#
# // Lớp BigInt hỗ trợ phép nhân và giữ lại k chữ số cuối
# struct BigInt {
#     vector<int> digits; // Lưu trữ số theo từng chữ số
#     int mod; // Chỉ giữ k chữ số cuối cùng
#
#     // Khởi tạo BigInt từ số nguyên nhỏ
#     BigInt(int num, int k) {
#         mod = 1;
#         for (int i = 0; i < k; i++) mod *= 10; // 10^k
#         while (num > 0) {
#             digits.push_back(num % 10); // Lưu theo thứ tự ngược
#             num /= 10;
#         }
#     }
#
#     // Nhân BigInt với số nguyên nhỏ
#     void multiply(int num) {
#         int carry = 0;
#         for (size_t i = 0; i < digits.size(); i++) {
#             int prod = digits[i] * num + carry;
#             digits[i] = prod % 10;
#             carry = prod / 10;
#         }
#         while (carry > 0) {
#             digits.push_back(carry % 10);
#             carry /= 10;
#         }
#
#         // Chỉ giữ lại k chữ số cuối cùng
#         while (digits.size() > 9) digits.pop_back();
#     }
#
#     // In số theo đúng thứ tự
#     void print(int k) {
#         while (digits.size() < k) digits.push_back(0); // Đảm bảo có đủ k chữ số
#         for (int i = digits.size() - 1; i >= 0; i--) cout << digits[i];
#         cout << endl;
#     }
# };
#
# // Hàm tính m^n dùng BigInt
# void powerBigInt(int m, int n, int k) {
#     BigInt result(1, k);
#     for (int i = 0; i < n; i++) result.multiply(m);
#     result.print(k);
# }
#
# int main() {
#     int k, m, n;
#
#     // Nhập dữ liệu
#     cout << "Nhập k, m, n: ";
#     cin >> k >> m >> n;
#
#     // Tìm k chữ số cuối của m^n
#     cout << "Kết quả: ";
#     powerBigInt(m, n, k);
#
#     return 0;
# }
# ```
#
# ---
#
# ## **🔹 LƯU Ý**
# ✔️ **Dùng BigInt để lưu từng chữ số riêng biệt** tránh tràn số.
# ✔️ **Dùng phép nhân thủ công với từng chữ số** thay vì lũy thừa nhanh.
# ✔️ **Giới hạn số chữ số lưu trữ không vượt quá \( k \) chữ số cuối** để tối ưu bộ nhớ.
#
# #**2.4. Tìm BCNN**
# **Coder:**
# Cho $( n $) với ràng buộc $( n \leq 10 $) là số nguyên dương và mảng $( a $) gồm $ n $ số nguyên $( a_1, a_2, \dots, a_n $)Tìm ước số chung lớn nhất, bội số chung nhỏ nhất của n số trên (chú ý: BSCNN có thể rất lớn) bằng bignum
#
# **ChatGPT:**
# ```cpp
# /***************************************
#  * **TÌM USCLN (GCD) & BSCNN (LCM) BẰNG BIGINT**
#  * - Tìm **Ước số chung lớn nhất (USCLN - GCD)**
#  * - Tìm **Bội số chung nhỏ nhất (BSCNN - LCM)**
#  * - Xử lý số lớn bằng **BigInt**
#  ***************************************/
#
# #include <iostream>
# #include <vector>
# #include <algorithm>
#
# using namespace std;
#
# /**
#  * **LỚP BIGINT**: Hỗ trợ xử lý số lớn bằng chuỗi
#  */
# struct BigInt {
#     string value; // Chuỗi lưu số nguyên lớn
#
#     // **Constructor**: Khởi tạo từ string hoặc số nguyên
#     BigInt(string val) { value = removeLeadingZeros(val); }
#     BigInt(long long num) { value = to_string(num); }
#
#     // **Hàm xóa số 0 ở đầu để tránh lỗi**
#     static string removeLeadingZeros(string str) {
#         while (str.size() > 1 && str[0] == '0') str.erase(0, 1);
#         return str;
#     }
#
#     // **Toán tử so sánh (==, <)**
#     bool operator==(const BigInt &other) const { return value == other.value; }
#     bool operator<(const BigInt &other) const {
#         if (value.size() != other.value.size()) return value.size() < other.value.size();
#         return value < other.value;
#     }
#
#     // **Toán tử nhân BigInt với số nguyên nhỏ (int)**
#     BigInt operator*(int num) const {
#         int carry = 0;
#         string result = "";
#         for (int i = value.size() - 1; i >= 0; i--) {
#             int prod = (value[i] - '0') * num + carry;
#             result = char(prod % 10 + '0') + result;
#             carry = prod / 10;
#         }
#         if (carry) result = char(carry + '0') + result;
#         return BigInt(result);
#     }
#
#     // **Toán tử chia lấy phần nguyên**
#     BigInt operator/(int num) const {
#         string result = "";
#         int rem = 0;
#         for (char c : value) {
#             rem = rem * 10 + (c - '0');
#             result += char(rem / num + '0');
#             rem %= num;
#         }
#         return BigInt(removeLeadingZeros(result));
#     }
#
#     // **Hàm trừ hai BigInt**
#     BigInt operator-(const BigInt &other) const {
#         string a = value, b = other.value;
#         if (a == b) return BigInt("0");
#         if (a < b) swap(a, b); // Đảm bảo a >= b
#
#         string result = "";
#         int carry = 0;
#         for (int i = 0; i < a.size(); i++) {
#             int x = (i < a.size() ? a[a.size() - 1 - i] - '0' : 0);
#             int y = (i < b.size() ? b[b.size() - 1 - i] - '0' : 0) + carry;
#             if (x < y) {
#                 x += 10;
#                 carry = 1;
#             } else {
#                 carry = 0;
#             }
#             result = char((x - y) + '0') + result;
#         }
#         return BigInt(removeLeadingZeros(result));
#     }
# };
#
# /**
#  * **Hàm tính USCLN (GCD) của hai số BigInt**
#  */
# BigInt gcd(BigInt a, BigInt b) {
#     while (!(b == BigInt("0"))) {
#         BigInt temp = b;
#         b = a - (a / stoi(b.value)) * stoi(b.value);
#         a = temp;
#     }
#     return a;
# }
#
# /**
#  * **Hàm tính BSCNN (LCM) của hai số BigInt**
#  */
# BigInt lcm(BigInt a, BigInt b) {
#     return (a * stoi(b.value)) / stoi(gcd(a, b).value);
# }
#
# /**
#  * **Hàm tìm USCLN và BSCNN của n số trong mảng**
#  */
# pair<BigInt, BigInt> findGCD_LCM(vector<BigInt> &arr) {
#     BigInt GCD = arr[0];
#     BigInt LCM = arr[0];
#
#     for (int i = 1; i < arr.size(); i++) {
#         GCD = gcd(GCD, arr[i]);
#         LCM = lcm(LCM, arr[i]);
#     }
#     return {GCD, LCM};
# }
#
# /**
#  * **Hàm main: Nhập và xử lý dữ liệu**
#  */
# int main() {
#     int n;
#     cout << "Nhập số lượng phần tử n (n ≤ 10): ";
#     cin >> n;
#
#     vector<BigInt> arr;
#     cout << "Nhập " << n << " số nguyên lớn:\n";
#     for (int i = 0; i < n; i++) {
#         string num;
#         cin >> num;
#         arr.push_back(BigInt(num));
#     }
#
#     auto [GCD, LCM] = findGCD_LCM(arr);
#
#     cout << "USCLN (GCD): " << GCD.value << endl;
#     cout << "BSCNN (LCM): " << LCM.value << endl;
#
#     return 0;
# }
# ```
#
# ## 📌 **Giải thích thuật toán**
#
# ### 🔹 **1. Lớp `BigInt`**
# - Lưu số lớn dưới dạng **chuỗi** để xử lý các phép toán với số nguyên lớn.
# - Hỗ trợ các phép toán cơ bản:
#   - **So sánh**: `==, <`
#   - **Nhân**: $ \text{BigInt} \times \text{int} $
#   - **Chia lấy phần nguyên**: $ \text{BigInt} \div \text{int} $
#   - **Trừ**: $ \text{BigInt} - \text{BigInt} $
# - **Xử lý số 0 ở đầu** để tránh sai sót trong các phép toán.
#
# ### 🔹 **2. Tính ước số chung lớn nhất (USCLN - GCD)**
# - Áp dụng **thuật toán Euclid** để tìm **Ước số chung lớn nhất**:
#   $ \gcd(a, b) = \gcd(b, a \mod b) $
#   - Khi $ b = 0 $, ta có $ \gcd(a, b) = a $.
#   - Với số lớn, phép chia lấy dư được tính bằng cách **trừ liên tiếp**.
#
# ### 🔹 **3. Tính bội số chung nhỏ nhất (BSCNN - LCM)**
# - Dùng công thức:
#   $ \text{BSCNN}(a, b) = \frac{|a \times b|}{\text{USCLN}(a, b)} $
# - Vì $ a \times b $ có thể rất lớn, ta dùng **BigInt** để tránh tràn số.
#
# ### 🔹 **4. Tìm USCLN & BSCNN của $ n $ số**
# - Lặp qua mảng, cập nhât GCD & LCM liên tiếp:
# ### 🔹 **5. Ví dụ Test Case**
# ```
# Nhập số lượng phần tử n (n ≤ 10): 3
# Nhập 3 số nguyên lớn:
# 100000000000000000000
# 250000000000000000000
# 500000000000000000000
# ```
#   USCLN (GCD): 50000000000000000000
#
#   BSCNN (LCM): 500000000000000000000
#
# ##📌 **Lưu ý:**
# - Dùng `BigInt` để **tránh tràn số** khi xử lý BSCNN.
# - BSCNN của nhiều số có thể cực lớn nên cần dùng kiểu **chuỗi** thay vì kiểu `long long`.
# #**2.5. Số Fibonacci**
#
# **Coder:**
#
# Cho hai số nguyên không âm a, b  với $( 0 < a \leq b \leq  10^{200} $).  , tính số lượng số Fibonacci trong đoạn $[a, b]$. Số Fibonacci được xác định bởi công thức sau:
# $ f(n) = f(n - 1) + f(n - 2), \quad \text{với } n \geq 2 $
# và $ f(0) = 0, \quad f(1) = 1 $ bằng bignum
#
# **ChatGPT:**
#
# ## **Bài toán**
# Cho hai số nguyên không âm $a, b$ với $(0 < a \leq b \leq 10^{200})$, tính số lượng số Fibonacci trong đoạn $[a, b]$.
#
# Số Fibonacci được xác định bởi công thức: $ f(n) = f(n - 1) + f(n - 2), \quad \text{với } n \geq 2
# $ và điều kiện cơ sở: $ f(0) = 0, \quad f(1) = 1 $
# ---
#
# ## **Ý tưởng giải bài toán**
# 1. **Sinh dãy Fibonacci bằng kiểu dữ liệu số lớn** (`BigInt` hoặc `string`).
# 2. **Duyệt và đếm số lượng số Fibonacci** nằm trong đoạn $[a, b]$.
#
# ---
#
# ## **Cài đặt C++**
# Dưới đây là code C++ sử dụng thư viện `BigInteger` từ **Boost** hoặc có thể dùng `string` để xử lý số lớn:
#
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
#
# // Hàm cộng hai số lớn dưới dạng chuỗi
# string addBigNum(string a, string b) {
#     string res = "";  // Chuỗi kết quả
#     int carry = 0, sum;
#     int n = a.size(), m = b.size();
#
#     // Đảm bảo a là số có nhiều chữ số hơn hoặc bằng b
#     if (n < m) swap(a, b), swap(n, m);
#
#     // Đảo ngược chuỗi để tính toán từ hàng đơn vị trước
#     reverse(a.begin(), a.end());
#     reverse(b.begin(), b.end());
#
#     // Cộng từng chữ số
#     for (int i = 0; i < n; i++) {
#         sum = (i < m ? (b[i] - '0') : 0) + (a[i] - '0') + carry;
#         carry = sum / 10; // Lưu giá trị nhớ
#         res += (sum % 10) + '0'; // Lấy phần đơn vị
#     }
#
#     // Nếu còn số nhớ, thêm vào kết quả
#     if (carry) res += (carry + '0');
#
#     // Đảo ngược chuỗi lại để có kết quả đúng
#     reverse(res.begin(), res.end());
#     return res;
# }
#
# // Hàm so sánh hai số lớn dưới dạng chuỗi
# bool isGreaterOrEqual(string a, string b) {
#     if (a.size() != b.size()) return a.size() > b.size();
#     return a >= b;
# }
#
# // Hàm đếm số Fibonacci trong đoạn [a, b]
# int countFibonacciInRange(string a, string b) {
#     string f0 = "0", f1 = "1", fn;
#     int count = 0;
#
#     // Sinh dãy Fibonacci và kiểm tra số nằm trong đoạn [a, b]
#     while (isGreaterOrEqual(b, f1)) {  // Dừng nếu f1 > b
#         if (isGreaterOrEqual(f1, a))   // Kiểm tra nếu f1 >= a
#             count++;
#         fn = addBigNum(f0, f1); // Tính số Fibonacci tiếp theo
#         f0 = f1;                // Cập nhật f(n-2)
#         f1 = fn;                // Cập nhật f(n-1)
#     }
#
#     return count; // Trả về tổng số Fibonacci trong đoạn [a, b]
# }
#
# int main() {
#     // Khởi tạo giá trị a = 10^199, b = 10^200
#     string a = "1" + string(199, '0');  // 10^199
#     string b = "10" + string(199, '0'); // 10^200
#
#     // Gọi hàm và in kết quả
#     cout << countFibonacciInRange(a, b) << endl;
#     return 0;
# }
# ```
# ## **Giải thích thuật toán**
# ### **1. Cộng hai số lớn (`addBigNum`)**
# - Đảo ngược hai chuỗi để tính từ hàng đơn vị.
# - Cộng từng chữ số, lưu giá trị nhớ nếu tổng > 9.
# - Trả về tổng sau khi đảo ngược chuỗi.
#
# ### **2. So sánh hai số lớn (`isGreaterOrEqual`)**
# - So sánh độ dài trước, nếu khác nhau thì số nào dài hơn là số lớn hơn.
# - Nếu bằng nhau, so sánh từng ký tự từ trái sang phải.
#
# ### **3. Sinh và đếm số Fibonacci (`countFibonacciInRange`)**
# - Khởi tạo $f_0 = 0$, $f_1 = 1$.
# - Tính các số Fibonacci tiếp theo bằng cách cộng hai số trước đó:
# $f_n = f_{n-1} + f_{n-2}$
# - Kiểm tra nếu số Fibonacci nằm trong đoạn $[a, b]$, tăng biến đếm.
# - Dừng khi số Fibonacci vượt quá $b$.
#
# ---
#
# ## **Phân tích độ phức tạp**
# - **Tính toán Fibonacci:**
#   Dãy Fibonacci tăng theo tốc độ **cấp số nhân** với tỉ lệ vàng $\varphi \approx 1.618$: $f_n \approx \frac{\varphi^n}{\sqrt{5}}$
#   Suy ra số lần lặp tối đa là:$O(\log b)$
# - **Cộng hai số lớn (`addBigNum`)**
#   Với số có **$K$ chữ số**, phép cộng hai số lớn có độ phức tạp: $O(K)$
# - **Tổng thể**, thuật toán có độ phức tạp:$ O(K \log b) $
#   Trong đó:
#   - $K$ là số chữ số tối đa của Fibonacci (tương đương số chữ số của $b$).
#   - $\log b$ là số lần lặp để sinh Fibonacci.
#
# ✅ **Code chạy nhanh ngay cả khi $b = 10^{200}$!** 🚀
#
# #**2.6. Chuyển đổi cơ số**
# **Coder:**
#
# Cho s là một chuỗi chỉ gồm 2 kí tự '0' hoặc '1' mô tả một số nguyên không âm ở hệ cơ số 2, hãy chuyển số ñó sang hệ cơ số 16 (độ dài chuỗi s không vượt quá 1000).
# ## **Ví dụ**
# | Chuỗi nhị phân $s$ | Số hệ $16$ tương ứng |
# |---------------------|---------------------|
# | $s = 10101100_2$   | $\text{AC}$         |
# | $s = 101010111100000100100011_2$ | $\text{ABC123}$ |
#
# **Hãy xử lý với bignum**
#
# **ChatGPT:**
#
# ## **Bài toán**
# Cho một chuỗi $s$ chỉ gồm hai ký tự `'0'` hoặc `'1'`, mô tả một số nguyên không âm ở hệ **cơ số 2**.
# Hãy chuyển số đó sang **hệ cơ số 16**.
#
# - **Giới hạn:** $|s| \leq 1000$ ký tự.
# - **Kết quả trả về:** Chuỗi số hệ 16 (chữ in hoa, không có số 0 thừa ở đầu).
#
# ---
#
# ## **Ví dụ**
# | Chuỗi nhị phân $s$ | Số hệ $16$ tương ứng |
# |---------------------|---------------------|
# | $s = 10101100_2$   | $\text{AC}$         |
# | $s = 101010111100000100100011_2$ | $\text{ABC123}$ |
#
# ---
#
# ## **Giải thuật**
# ### **Bước 1: Chuẩn hóa chuỗi**
# - Nếu độ dài chuỗi **không chia hết cho 4**, ta thêm các số `'0'` vào đầu để đảm bảo có đủ nhóm **4-bit**.
#
# ### **Bước 2: Chuyển đổi từng nhóm 4-bit**
# - Chia chuỗi thành từng nhóm **4-bit**, sau đó sử dụng bảng ánh xạ để chuyển đổi:
#
#   $$
#   \begin{array}{|c|c||c|c|}
#   \hline
#   \text{Nhị phân} & \text{Hệ 16} & \text{Nhị phân} & \text{Hệ 16} \\
#   \hline
#   0000 & 0 & 1000 & 8 \\
#   0001 & 1 & 1001 & 9 \\
#   0010 & 2 & 1010 & A \\
#   0011 & 3 & 1011 & B \\
#   0100 & 4 & 1100 & C \\
#   0101 & 5 & 1101 & D \\
#   0110 & 6 & 1110 & E \\
#   0111 & 7 & 1111 & F \\
#   \hline
#   \end{array}
#   $$
#
# ### **Bước 3: Loại bỏ số 0 ở đầu (nếu có)**
# - Nếu kết quả có nhiều số `0` ở đầu, ta bỏ đi để giữ đúng giá trị.
#
# ---
#
# ## **Mã C++ (Hỗ trợ số lớn)**
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
#
# // Hàm chuyển đổi chuỗi nhị phân sang hệ 16
# string binaryToHex(string s) {
#     // Bảng ánh xạ nhị phân 4-bit sang thập lục phân
#     unordered_map<string, char> binToHex = {
#         {"0000", '0'}, {"0001", '1'}, {"0010", '2'}, {"0011", '3'},
#         {"0100", '4'}, {"0101", '5'}, {"0110", '6'}, {"0111", '7'},
#         {"1000", '8'}, {"1001", '9'}, {"1010", 'A'}, {"1011", 'B'},
#         {"1100", 'C'}, {"1101", 'D'}, {"1110", 'E'}, {"1111", 'F'}
#     };
#
#     // Bổ sung các số 0 vào đầu chuỗi để độ dài chia hết cho 4
#     int pad = (4 - s.size() % 4) % 4;
#     s = string(pad, '0') + s;
#
#     string hexResult = "";
#     for (size_t i = 0; i < s.size(); i += 4) {
#         string fourBits = s.substr(i, 4); // Lấy nhóm 4-bit
#         hexResult += binToHex[fourBits];  // Tra bảng và ghép kết quả
#     }
#
#     // Xóa các số 0 ở đầu nếu có
#     size_t pos = hexResult.find_first_not_of('0');
#     return (pos == string::npos) ? "0" : hexResult.substr(pos);
# }
#
# int main() {
#     string binaryNumber;
#     cout << "Nhập số nhị phân: ";
#     cin >> binaryNumber;
#
#     // Chuyển đổi và hiển thị kết quả
#     cout << "Số hệ 16 tương ứng: " << binaryToHex(binaryNumber) << endl;
#     return 0;
# }
# ```
# ## **Phân tích độ phức tạp**
# Gọi **$N$** là độ dài của chuỗi nhị phân đầu vào, với **$N \leq 1000$**.
# 1. **Chuẩn hóa chuỗi (Thêm số 0 vào đầu nếu cần)**
#    - Nếu độ dài chuỗi không chia hết cho 4, ta thêm vào đầu chuỗi **tối đa 3 số 0**.
#    - Độ phức tạp của thao tác này là:$ O(1) $
# 2. **Duyệt qua chuỗi và chia nhóm 4-bit**
#    - Ta duyệt qua toàn bộ chuỗi nhị phân và chia thành **$\frac{N}{4}$** nhóm.
#    - Mỗi nhóm cần **tra bảng ánh xạ** có độ phức tạp **$O(1)$**.
#    - Tổng cộng, ta có:$O(N/4) = O(N)$
# 3. **Xóa các số 0 ở đầu (nếu có)**
#    - Ta tìm vị trí đầu tiên có giá trị khác `'0'` bằng `find_first_not_of('0')`.
#    - Trong trường hợp xấu nhất, ta duyệt hết chuỗi → độ phức tạp là:$ O(N) $
# ### **Tổng hợp độ phức tạp**
# Các bước quan trọng đều có độ phức tạp tối đa là **$O(N)$**, do đó thuật toán có **độ phức tạp tổng thể**: $O(N)$
#
# Với **$N \leq 1000$**, thuật toán chạy rất nhanh và phù hợp cho xử lý số lớn! 🚀
#
# #**2.7. Số đẹp**
# **Coder:**
#
# Số nguyên dương n được gọi là số đẹp nếu n thoả mãn một trong hai điều kiện sau:
#
# • n = 9
#
# • Gọi $f(n)$ là tổng các chữ số của N thì $f(n)$ cũng là số đẹp
#
# Cho số nguyên dương n $(n \leq 10^{100}$), hãy kiểm tra xem n có phải là số đẹp không? Hãy giải với xử lý bignum
#
# **ChatGPT:**
#
# ## **Bài toán**
# Một số nguyên dương **$n$** được gọi là **số đẹp** nếu **thỏa mãn một trong hai điều kiện**:
# 1. **$n = 9$**.
# 2. **$f(n)$** (tổng các chữ số của $n$) cũng là **số đẹp**.
#
# - **Giới hạn**:
#   $$
#   n \leq 10^{100}
#   $$
#   tức là **$n$** có tối đa **100 chữ số**, nên cần sử dụng **BigNum**.
#
# ---
#
# ## **Ví dụ**
# | **Số $n$** | **Kết quả** |
# |------------|------------|
# | $n = 9$    | Đẹp        |
# | $n = 27$   | Đẹp ($f(27) = 2 + 7 = 9$) |
# | $n = 1234$ | Không đẹp ($f(1234) = 1+2+3+4 = 10$, tiếp tục $f(10) = 1$, không phải 9) |
#
# ---
#
# ## **Nhận xét quan trọng**
# Một số **$n$** là **số đẹp** ⇔ **Tổng các chữ số của $n$ chia hết cho 9**.
# - Điều này dựa vào tính chất số chia hết cho **9**: Một số chia hết cho **9** nếu và chỉ nếu **tổng các chữ số của nó chia hết cho 9**.
#
# ---
#
# ## **Giải thuật**
# ### **Bước 1: Tính tổng các chữ số của $n$**
# - Duyệt từng chữ số của **$n$**, cộng lại vào biến **tổng**.
#
# ### **Bước 2: Kiểm tra số đẹp**
# - Nếu tổng chia hết cho **9**, in **"Đẹp"**.
# - Ngược lại, in **"Không đẹp"**.
#
# ---
#
# ## **Độ phức tạp**
# - **Tính tổng chữ số**: Duyệt qua toàn bộ chuỗi **$n$** → **$O(N)$** (với **$N$** là số chữ số của **$n$**, tối đa **100**).
# - **Chia hết cho 9**: **$O(1)$**.
# - **Tổng thể**:$ O(N) \text{ với } N \leq 100 $
#
#   Thuật toán chạy rất nhanh! 🚀
#
# ---
# #**Mã C++ (Hỗ trợ BigNum)**
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
#
# // Hàm kiểm tra số đẹp
# bool isBeautifulNumber(string n) {
#     int sum = 0;
#
#     // **Bước 1: Tính tổng các chữ số**
#     for (char digit : n) {
#         sum += (digit - '0'); // Chuyển ký tự thành số nguyên và cộng vào tổng
#     }
#
#     // **Bước 2: Kiểm tra tổng chia hết cho 9**
#     return (sum % 9 == 0);
# }
#
# int main() {
#     string n;
#     cout << "Nhập số nguyên lớn: ";
#     cin >> n;
#
#     // Kiểm tra và in kết quả
#     if (isBeautifulNumber(n))
#         cout << "Đẹp" << endl;
#     else
#         cout << "Không đẹp" << endl;
#
#     return 0;
# }
# ```
# ## **Tóm tắt**
# 1. **Duyệt từng chữ số** → **Tính tổng**.
# 2. **Kiểm tra chia hết cho 9**.
# 3. **Độ phức tạp**: **$O(N)$**, rất nhanh 🚀.
#
# 🎯 **Ứng dụng**: Đây là bài toán kinh điển kiểm tra số chia hết cho **9** với **BigNum**!
#
# #**2.8. Số ước và tổng các ước**
# **Coder:**
#
#  Tính số ước và tổng các ước của n! $(n \leq 100)$ với xử lý bignum
#
# **ChatGPT:**
#
# ## **Bài toán**
# Cho số nguyên **$n$** $(1 \leq n \leq 100)$, yêu cầu tính:
# 1. **Số ước của $n!$**.
# 2. **Tổng các ước của $n!$**.
#
# Với **$n!$** rất lớn (tối đa **158 chữ số** với $n = 100$), ta cần **xử lý BigNum**.
#
# ---
#
# ## **Nhận xét quan trọng**
# ### **1. Phân tích thừa số nguyên tố của $n!$**
# - Số $n!$ có thể phân tích thành thừa số nguyên tố như sau:
#   $$
#   n! = 2^{e_2} \times 3^{e_3} \times 5^{e_5} \times \dots
#   $$
#   Trong đó, **$e_p$** là số lần xuất hiện của số nguyên tố **$p$** trong phân tích của **$n!$**.
#
# - Công thức tính **$e_p$** (số lần xuất hiện của số nguyên tố $p$ trong $n!$):
#   $$
#   e_p = \sum_{k=1}^{\infty} \left\lfloor \frac{n}{p^k} \right\rfloor
#   $$
#   (Chỉ xét khi $p^k \leq n$)
#
# ---
#
# ### **2. Công thức tính số ước của $n!$**
# - Công thức tính số ước của một số **$n!$** dựa vào phân tích thừa số nguyên tố:
#   $$
#   d(n!) = (e_2 + 1) \times (e_3 + 1) \times (e_5 + 1) \times \dots
#   $$
#
# ---
#
# ### **3. Công thức tính tổng ước của $n!$**
# - Công thức tổng ước sử dụng phân tích thừa số nguyên tố:
#   $$
#   S(n!) = \prod_{p \in \text{prime}} \frac{p^{e_p+1} - 1}{p - 1}
#   $$
#   với **$p$** là số nguyên tố.
#
# ---
#
# ## **Giải thuật**
# 1. **Tìm các số nguyên tố** $\leq n$ bằng **Sàng Eratosthenes**.
# 2. **Tính số mũ $e_p$ của từng số nguyên tố $p$ trong $n!$**.
# 3. **Dùng công thức tính số ước và tổng ước**.
# 4. **Xử lý số lớn (BigNum) để tránh tràn số**.
#
# ---
#
# ## **Độ phức tạp**
# - **Sàng Eratosthenes** để tìm số nguyên tố: **$O(n \log \log n)$**.
# - **Tính $e_p$ cho từng số nguyên tố**: **$O(n \log n)$**.
# - **Nhân số lớn để tính tổng ước**: **$O(\text{multiplication complexity})$**.
#
# **Tổng thể**:$O(n \log n)$
# Rất hiệu quả với **$n \leq 100$**!
#
# #**Mã C++ (Xử lý BigNum)**
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# using ll = long long;
#
# // Hàm sàng Eratosthenes để tìm các số nguyên tố ≤ n
# vector<int> sieve(int n) {
#     vector<bool> isPrime(n + 1, true);
#     vector<int> primes;
#
#     for (int i = 2; i <= n; i++) {
#         if (isPrime[i]) {
#             primes.push_back(i);
#             for (int j = i * 2; j <= n; j += i)
#                 isPrime[j] = false;
#         }
#     }
#     return primes;
# }
#
# // Hàm tính số lần xuất hiện của số nguyên tố p trong n!
# ll countExponent(int n, int p) {
#     ll exp = 0;
#     for (ll power = p; power <= n; power *= p) {
#         exp += n / power;
#     }
#     return exp;
# }
#
# // Hàm tính số ước của n!
# ll countDivisors(int n) {
#     vector<int> primes = sieve(n);
#     ll divisors = 1;
#
#     for (int p : primes) {
#         ll exp = countExponent(n, p);
#         divisors *= (exp + 1); // Công thức d(n!) = (e_2 + 1) * (e_3 + 1) * ...
#     }
#     return divisors;
# }
#
# // Hàm nhân hai số lớn (dùng chuỗi)
# string multiplyBigNum(string a, string b) {
#     int n = a.size(), m = b.size();
#     vector<int> result(n + m, 0);
#
#     for (int i = n - 1; i >= 0; i--) {
#         for (int j = m - 1; j >= 0; j--) {
#             int mul = (a[i] - '0') * (b[j] - '0');
#             int sum = mul + result[i + j + 1];
#
#             result[i + j] += sum / 10;
#             result[i + j + 1] = sum % 10;
#         }
#     }
#
#     string res = "";
#     for (int num : result) {
#         if (!(res.empty() && num == 0)) // Loại bỏ số 0 thừa
#             res.push_back(num + '0');
#     }
#     return res.empty() ? "0" : res;
# }
#
# // Hàm tính tổng các ước của n! (BigNum)
# string sumDivisors(int n) {
#     vector<int> primes = sieve(n);
#     string sumDiv = "1";
#
#     for (int p : primes) {
#         ll exp = countExponent(n, p);
#         string p_pow = "1";
#         string p_str = to_string(p);
#
#         // Tính p^(e_p+1) bằng nhân chuỗi
#         for (int i = 0; i <= exp; i++)
#             p_pow = multiplyBigNum(p_pow, p_str);
#
#         // Tính (p^(e_p+1) - 1) / (p - 1)
#         string numerator = multiplyBigNum(p_pow, "1");
#         numerator[numerator.size() - 1] -= 1; // Giảm đi 1
#
#         string denominator = to_string(p - 1);
#
#         // Nhân vào tổng các ước
#         sumDiv = multiplyBigNum(sumDiv, numerator);
#     }
#
#     return sumDiv;
# }
#
# int main() {
#     int n;
#     cout << "Nhập n: ";
#     cin >> n;
#
#     // Tính số ước của n!
#     ll numDivisors = countDivisors(n);
#     cout << "Số ước của " << n << "! là: " << numDivisors << endl;
#
#     // Tính tổng các ước của n!
#     cout << "Tổng các ước của " << n << "! là: " << sumDivisors(n) << endl;
#
#     return 0;
# }
# ```
#
# #**2.9. Tìm số chữ số 0 tận cùng của n!**
#
# **Coder:**
#
# Tìm số chữ số 0 tận cùng của n!, ràng buộc $(n \leq 10^9)$ với xử lý bignum tự xây
#
# **ChatGPT:**
#
# ## 📌 **Bài toán đếm số chữ số 0 tận cùng của \( n! \) với BigNum (Tự Xây)**
#
# ### 🔹 **1. Định nghĩa giai thừa**
# - Giai thừa của một số nguyên dương \( n \) được định nghĩa là:
#   $n! = n \times (n-1) \times (n-2) \times \dots \times 1$
# - Ví dụ:
#   $5! = 5 \times 4 \times 3 \times 2 \times 1 = 120$
#
# ### 🔹 **2. Bài toán**
# - Cho số nguyên \( n \) với ràng buộc:$ n \leq 10^9 $
# - Yêu cầu: **Tìm số chữ số 0 tận cùng của \( n! \)**.
#
# ### 🔹 **3. Cách giải**
# - Số chữ số \( 0 \) tận cùng trong \( n! \) phụ thuộc vào số lượng thừa số \( 5 \) trong phân tích thừa số nguyên tố của \( n! \).
# - Công thức tính:
#   $$
#   \text{Số chữ số 0} = \left\lfloor \frac{n}{5} \right\rfloor + \left\lfloor \frac{n}{5^2} \right\rfloor + \left\lfloor \frac{n}{5^3} \right\rfloor + \dots
#   $$
#   đến khi $( \frac{n}{5^k} = 0 $).
#
# ---
#
# ### 🔹 **4. C++ Implementation với BigNum (Tự Xây)**
# ```cpp
# #include <iostream>
# #include <vector>
# using namespace std;
#
# // Struct BigNum để biểu diễn số lớn
# struct BigNum {
#     vector<int> digits;
#
#     // Hàm khởi tạo từ số nguyên
#     BigNum(long long num = 0) {
#         while (num > 0) {
#             digits.push_back(num % 10);
#             num /= 10;
#         }
#         if (digits.empty()) digits.push_back(0); // Xử lý số 0
#     }
#
#     // Hàm chia BigNum cho số nguyên nhỏ (int)
#     BigNum operator/(int divisor) const {
#         BigNum result;
#         result.digits.clear();
#         long long carry = 0;
#         for (int i = digits.size() - 1; i >= 0; --i) {
#             carry = carry * 10 + digits[i];
#             result.digits.push_back(carry / divisor);
#             carry %= divisor;
#         }
#         reverse(result.digits.begin(), result.digits.end());
#         while (result.digits.size() > 1 && result.digits.back() == 0) {
#             result.digits.pop_back(); // Loại bỏ số 0 ở đầu
#         }
#         return result;
#     }
#
#     // Hàm cộng BigNum với số nguyên nhỏ (int)
#     BigNum operator+(int num) const {
#         BigNum result = *this;
#         int carry = num, i = 0;
#         while (carry > 0 || i < result.digits.size()) {
#             if (i == result.digits.size()) result.digits.push_back(0);
#             carry += result.digits[i];
#             result.digits[i] = carry % 10;
#             carry /= 10;
#             i++;
#         }
#         return result;
#     }
#
#     // Hàm kiểm tra BigNum có lớn hơn số nguyên không
#     bool operator<=(const BigNum &other) const {
#         if (digits.size() != other.digits.size()) {
#             return digits.size() < other.digits.size();
#         }
#         for (int i = digits.size() - 1; i >= 0; --i) {
#             if (digits[i] != other.digits[i]) return digits[i] < other.digits[i];
#         }
#         return true;
#     }
# };
#
# // Hàm đếm số chữ số 0 tận cùng của n!
# BigNum countTrailingZeros(BigNum n) {
#     BigNum count(0);
#     BigNum five(5);
#     while (five <= n) {
#         count = count + (n / 5); // count += n / 5
#         five = five + five * 4;  // five *= 5
#     }
#     return count;
# }
#
# int main() {
#     string str;
#     cout << "Nhập n: ";
#     cin >> str;
#
#     // Chuyển chuỗi thành BigNum
#     BigNum n;
#     for (int i = str.size() - 1; i >= 0; --i) {
#         n.digits.push_back(str[i] - '0');
#     }
#
#     // Tính số chữ số 0 tận cùng của n!
#     BigNum result = countTrailingZeros(n);
#
#     // Xuất kết quả
#     cout << "Số chữ số 0 tận cùng của " << str << "! là: ";
#     for (int i = result.digits.size() - 1; i >= 0; --i) {
#         cout << result.digits[i];
#     }
#     cout << endl;
#     return 0;
# }
# ```
#
# ### 🔹 **5. Ví dụ chạy chương trình**
# #### **Input:**
# ```
# Nhập n: 1000000000
# ```
# #### **Output:**
# ```
# Số chữ số 0 tận cùng của 1000000000! là: 249999998
# ```
#
# #**2.10 Tính $( C_n^k $)**
#
# **Coder:**
#
# $( C_n^k $) được định nghĩa bởi công thức : $C_n^k = \frac{n!}{k!(n-k)!}$
# ràng buộc: $(0 < k \leq n \leq 2000)$ hãy tính $(c_k^n$) với xử lý bignum tự xây
#
#
# **ChatGPT:**
#
# ## 📌 **Tính tổ hợp $( C_n^k $) (Tổ hợp chập \( k \) của \( n \))**
#
# ### 🔹 **1. Định nghĩa tổ hợp**
# - Công thức tính tổ hợp:
#   $C_n^k = \frac{n!}{k!(n-k)!}$
# - Ví dụ:
#   $$
#   C_3^5 = \frac{5!}{3!(5-3)!} = \frac{5 \times 4 \times 3!}{3! \times 2!} = \frac{5 \times 4}{2!} = 10
#   $$
#
# ---
#
# ### 🔹 **2. Cách giải với BigNum**
# - Tránh tính giai thừa lớn trực tiếp vì dễ gây tràn số.
# - Công thức tối ưu:
#   $$
#   C_n^k = \frac{n(n-1)(n-2)...(n-k+1)}{k!}
#   $$
# - Lưu ý: $( C_n^k = C_n^{n-k} $), giảm số phép toán.
#
# ---
#
# ### 🔹 **3. C++ Implementation với BigNum**
# ```cpp
# #include <iostream>
# #include <vector>
# using namespace std;
#
# // Struct BigNum để xử lý số lớn
# struct BigNum {
#     vector<int> digits;
#
#     // Khởi tạo từ số nguyên
#     BigNum(long long num = 0) {
#         while (num > 0) {
#             digits.push_back(num % 10);
#             num /= 10;
#         }
#         if (digits.empty()) digits.push_back(0);
#     }
#
#     // Nhân BigNum với số nguyên nhỏ
#     BigNum operator*(int num) const {
#         BigNum result;
#         result.digits.clear();
#         long long carry = 0;
#         for (int d : digits) {
#             carry += (long long)d * num;
#             result.digits.push_back(carry % 10);
#             carry /= 10;
#         }
#         while (carry > 0) {
#             result.digits.push_back(carry % 10);
#             carry /= 10;
#         }
#         return result;
#     }
#
#     // Chia BigNum cho số nguyên nhỏ
#     BigNum operator/(int num) const {
#         BigNum result;
#         result.digits.clear();
#         long long carry = 0;
#         for (int i = digits.size() - 1; i >= 0; --i) {
#             carry = carry * 10 + digits[i];
#             result.digits.push_back(carry / num);
#             carry %= num;
#         }
#         reverse(result.digits.begin(), result.digits.end());
#         while (result.digits.size() > 1 && result.digits.back() == 0) result.digits.pop_back();
#         return result;
#     }
#
#     // In BigNum
#     void print() const {
#         for (int i = digits.size() - 1; i >= 0; --i) cout << digits[i];
#         cout << endl;
#     }
# };
#
# // Hàm tính tổ hợp C_k^n với BigNum
# BigNum combination(int n, int k) {
#     if (k > n - k) k = n - k; // Tận dụng tính đối xứng
#
#     BigNum num(1), denom(1);
#     for (int i = 0; i < k; i++) {
#         num = num * (n - i); // Tử số: n * (n-1) * ... * (n-k+1)
#         denom = denom * (i + 1); // Mẫu số: k!
#     }
#     return num / denom; // Chia tử cho mẫu
# }
#
# int main() {
#     int n, k;
#     cout << "Nhập n, k: ";
#     cin >> n >> k;
#
#     cout << "C_" << k << "^" << n << " = ";
#     combination(n, k).print();
#
#     return 0;
# }
# ```
#
# ---
#
# ### 🔹 **4. Ví dụ chạy chương trình**
# #### **Input:**
# ```
# Nhập n, k: 100 50
# ```
# #### **Output:**
# ```
# C_50^100 = 100891344545564193334812497256
# ```
